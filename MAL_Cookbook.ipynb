# %%
import requests
import json
import urllib
# importing selenium into code
from selenium import webdriver 
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time

# this constant should be modified according to where the web driver has been placed
WEBDRIVER_PATH = './'

#replace client_id with Client Key given at https://myanimelist.net/apiconfig
client_id = "d1ba6c8f42d9abdc2aa2d84fb61702e5"

base_url = "https://api.myanimelist.net/v2/"
auth_header = {"X-MAL-CLIENT-ID" : client_id}

# %%
# Get Anime List of turtlemage

#user = "turtlemage"
#content_type = "animelist"
# Construct url to HTTP GET
#url = base_url + "users/" + user + "/" + content_type

#fields = {
#    "fields" : "list_status"
#}
# Send HTTP GET Request
#r = requests.get(url, headers = auth_header, params = fields)
#print(r.status_code)
#
#full_json = r.json()
#next_request_url = full_json['paging']['next']
#print(full_json)




# Loop for paging through queries that may require more than 1 Request
#while 'paging' in full_json:
#    paging = full_json['paging']
#    new_url = paging['next']
#    r = requests.get(new_url, headers = auth_header)
# Status Code 200 means that the request is Successful (i.e not Rate Limited)
#    if r.status_code == 200:
# This appends the previous json with the newly obtained json
#        full_json['data'] += r.json()['data']
#        if 'next' in r.json()['paging']:
#            full_json['paging'] = r.json()['paging']
#        else:
#            full_json.pop('paging')
#print(full_json)

# %%
def get_user_list_ids(client_id, user, content_type='anime', fields='list_status', returnJSON=True, return_type='id'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    user         - username of user
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    fields       - list of fields to include in returned data, string deliminated by commas
    returnJSON   - boolean deciding whether to return raw JSON or to return simplified data
    return_type  - recommended id or title, determines the keys of formatted dictionary        
    """ 
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    #contentType is either anime or manga
    if content_type == 'anime':
        content = 'animelist'
    else:
        content = 'mangalist'
    data_request = {'fields' : fields}
    # Create request url, to pass HTTP GET request with header and fields
    url = base_url + "users/" + user + "/" + content
    # Initial HTTP request
    r = requests.get(url, headers = auth_header, params = data_request)
    if r.status_code != 200:
        raise Exception("HTTP GET Error : "+str(r.status_code))
    full_json = r.json()
    # Loops through all pages for lists that are too large for one HTTP GET
    while 'paging' in full_json:
        paging = full_json['paging']
        new_url = paging['next']
        r = requests.get(new_url, headers = auth_header)
        if r.status_code != 200:
            raise Exception("HTTP GET Error : "+str(r.status_code))
        full_json['data'] += r.json()['data']
        if 'next' in r.json()['paging']:
            full_json['paging'] = r.json()['paging']
        else:
            full_json.pop('paging')
    # Returns raw data if left alone
    if returnJSON:
        return full_json
    # Attempt at Cleaning the json up a bit for usability - not necessarily too useful
    else:
        shows = full_json['data']
    field_list = fields.split(',')
    show_list = {}
    for node in full_json['data']:
        try:
            show = node['node'][return_type]
            show_list[show] = {}
        except:
            raise Exception('return_type not valid - must be id, title, or other field type')
        for field in field_list:
            show_list[show][field] = node['node'][field]
    return show_list





def get_show_id(client_id, show_title, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_title   - title of show that an ID needs to be found for
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """ 
    # Allowing lists to be passed thru to simplify future code
    if type(show_title) is list:
        show_ids = []
        for show in show_title:
            show_id.append(get_show_id(client_id, show, content_type))
        return show_ids
    # Creating HTTP GET header
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    #contentType is either anime or manga
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Create request url, to pass HTTP GET request with header and fields
    # Uses MAL's search feature to find show
    url = base_url + content + "?q=" +  urllib.parse.quote(show_title.lower().split()[0])
    # Initial HTTP request
    r = requests.get(url,headers = auth_header)
    if r.status_code != 200:
        raise Exception("HTTP GET Error : "+str(r.status_code))
    for node in r.json()['data']:
        if node['node']['title'] == show_title:
            return node['node']['id']
    raise Exception("Title not Found")
    
    
    
    
    
    
    
def get_show_stats(client_id, show_ids=[], show_title=[], content_type='anime', stat='all'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_id      - integer relating to the index in MAL's database
    show_title   - title of show that an ID needs to be found for
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    stat         - statistic to be found (all returns default stats)
    """ 
    if type(show_ids) == int:
        show_ids = [show_ids]
    if show_ids == [] and show_title == []:
        raise Exception("Must submit an id or title")
    elif show_ids == []:
        for show in show_title:
            show_ids.append(get_show_id(client_id, show_title, content_type))
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    #contentType is either anime or manga
    if content_type == 'anime':
        content = 'anime/'
    else:
        content = 'manga/'
    # Loop through all shows and request (cant seen to figure out how to batch them other than using a temp holder acct)
    results = []
    for show in show_ids:
        # Create request url, to pass HTTP GET request with header and fields
        url = base_url + content + str(show)
        # Initial HTTP request
        r = requests.get(url, headers = auth_header, params = {'fields' : stat})
        results.append(r.json())
    if stat == 'all':
        return results
    else:
        amended_results = []
        for show in results:
            amended_results.append(show[stat])
        return amended_results

# %%
animelist = get_user_list_ids(client_id, 'turtlemage')
print(animelist)
print(get_show_id(client_id, "Yuukoku no Moriarty"))
# Out:
# {'data': [{'node': {'id': 38101, 'title': '5-toubun no Hanayome', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1819/97947.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1819/97947l.jpg'}}, 'list_status': {'status': 'dropped', 'score': 4, 'num_episodes_watched': 6, 'is_rewatching': False, 'updated_at': '2021-01-27T02:13:39+00:00'}}, {'node': {'id': 41457, 'title': '86', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1987/117507.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1987/117507l.jpg'}}, 'list_status': {'status': 'plan_to_watch', 'score': 0, 'num_episodes_watched': 0, 'is_rewatching': False, 'updated_at': '2022-01-20T06:52:31+00:00'}}, {'node': {'id': 32998, 'title': '91 Days', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/13/80515.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/13/80515l.jpg'}}, 'list_status': {'status': 'completed', 'score': 9, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2021-06-17T06:05:36+00:00', 'finish_date': '2021-06-17'}}, {'node': {'id': 25397, 'title': 'Absolute Duo', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/4/68839.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/4/68839l.jpg'}}, 'list_status': {'status': 'completed', 'score': 5, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2021-06-03T07:55:49+00:00'}}, {'node': {'id': 12291, 'title': 'Acchi Kocchi', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/5/46489.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/5/46489l.jpg'}}, 'list_status': {'status': 'completed', 'score': 10, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2020-11-26T11:05:24+00:00'}}, {'node': {'id': 22199, 'title': 'Akame ga Kill!', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1429/95946.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1429/95946l.jpg'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 24, 'is_rewatching': False, 'updated_at': '2020-11-26T10:48:52+00:00'}}, {'node': {'id': 22729, 'title': 'Aldnoah.Zero', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/7/60263.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/7/60263l.jpg'}}, 'list_status': {'status': 'completed', 'score': 6, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2021-06-03T07:55:36+00:00'}}, {'node': {'id': 36882, 'title': 'Arifureta Shokugyou de Sekai Saikyou', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1776/97682.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1776/97682l.jpg'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 13, 'is_rewatching': False, 'updated_at': '2020-11-26T11:01:17+00:00'}}, {'node': {'id': 40507, 'title': 'Arifureta Shokugyou de Sekai Saikyou 2nd Season', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1877/119668.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1877/119668l.jpg'}}, 'list_status': {'status': 'plan_to_watch', 'score': 0, 'num_episodes_watched': 0, 'is_rewatching': False, 'updated_at': '2021-12-21T08:39:00+00:00'}}, {'node': {'id': 28249, 'title': 'Arslan Senki (TV)', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/6/73588.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/6/73588l.jpg'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 25, 'is_rewatching': False, 'updated_at': '2021-06-03T08:01:07+00:00'}}, {'node': {'id': 6347, 'title': 'Baka to Test to Shoukanjuu', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/3/50389.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/3/50389l.jpg'}}, 'list_status': {'status': 'completed', 'score': 6, 'num_episodes_watched': 13, 'is_rewatchin ...
# 40911

# %%
def get_genre(client_id, show_ids, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_ids     - list of show indexes to get genre info about
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """ 
    # If only checking 1 show, puts single show into list wrapper
    if type(show_ids) == int:
        show_ids = [show_ids]
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    genre_dict = {}
    # For each show in list, HTTP GET genre
    for show in show_ids:
        url = base_url + content + "/" + str(show) + "?fields=genres"
        r = requests.get(url, headers=auth_header)
        genre_dict[show] = r.json()['genres']
    return genre_dict




def get_titles(client_id, show_id, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_id      - id of shows that alternate titles are needed for
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """ 
    # If only checking 1 show, puts single show into list wrapper
    if type(show_ids) == int:
        show_ids = [show_ids]
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    title_dict = {}
    # HTTP GET alternative titles for each show entry
    for show in show_id:
        url = base_url + content + "/" + str(show_id) + "?fields=title,alternative_titles"
        r = requests.get(url, headers=auth_header)
        title_dict[show] = r.json()['alternative_titles']
        title_dict[show]['popular_title'] = r.json()['title']
    return title_dict

# %%
get_genre(client_id, 40911)
# Out:
# {40911: [{'id': 13, 'name': 'Historical'},
#   {'id': 7, 'name': 'Mystery'},
#   {'id': 40, 'name': 'Psychological'},
#   {'id': 27, 'name': 'Shounen'},
#   {'id': 41, 'name': 'Suspense'}]}

# %%
def get_genre_preferences(client_id, user, content_type='anime', only_watched=True):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    user         - MAL username that is being analysed
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    only_watched - Set False if all entries (including Dropped and Plan to Watch) are to be analysed
    """
    # Get user animelist
    show_list = {}
    user_animelist = get_user_list_ids(client_id, user, content_type, fields='list_status')
    if only_watched:
        for node in user_animelist['data']:
            if node['list_status']['status'] == "completed":
                show_list[node['node']['id']] = node['list_status']['score']
    else:
        for node in user_anilist['data']:
            show_list[node['node']['id']] = node['list_status']['score']
    # Get show ids
    show_ids = []
    for key in show_list.keys():
        show_ids.append(key)
    # get genre info
    genre_list = get_genre(client_id, show_ids, content_type)
    genres = {}
    # iterate through genres to get count of number of shows with each genre tag and average user score
    for show in genre_list.keys():
        for genre in genre_list[show]:
            if genre['id'] not in genres.keys():
                genres[genre['id']] = {'genre': genre, 'count' : 1, 'avg_score' : show_list[show]}
            else:
                count = genres[genre['id']]['count'] + 1
                avg_score = (genres[genre['id']]['avg_score'] * (count - 1) + show_list[show]) / count
                genres[genre['id']]['count'] = count
                genres[genre['id']]['avg_score'] = avg_score
    return genres

# %%
get_genre_preferences(client_id, 'turtlemage')
# Out:
# {1: {'genre': {'id': 1, 'name': 'Action'},
#   'count': 70,
#   'avg_score': 7.442857142857143},
#  8: {'genre': {'id': 8, 'name': 'Drama'},
#   'count': 38,
#   'avg_score': 7.921052631578948},
#  13: {'genre': {'id': 13, 'name': 'Historical'},
#   'count': 10,
#   'avg_score': 8.8},
#  68: {'genre': {'id': 68, 'name': 'Organized Crime'},
#   'count': 3,
#   'avg_score': 7.666666666666667},
#  9: {'genre': {'id': 9, 'name': 'Ecchi'}, 'count': 22, 'avg_score': 6.5},
#  35: {'genre': {'id': 35, 'name': 'Harem'},
#   'count': 31,
#   'avg_score': 6.806451612903226},
#  22: {'genre': {'id': 22, 'name': 'Romance'},
#   'count': 60,
#   'avg_score': 7.266666666666667},
#  23: {'genre': {'id': 23, 'name': 'School'}, 'count': 45, 'avg_score': 7.6},
#  37: {'genre': {'id': 37, 'name': 'Supernatural'},
#   'count': 28,
#   'avg_score': 7.821428571428571},
#  4: {'genre': {'id': 4, 'name': 'Comedy'},
#   'count': 75,
#   'avg_score': 7.533333333333333},
#  57: {'genre': {'id': 57, 'name': 'Gag Humor'},
#   'count': 7,
#   'avg_score': 8.285714285714286},
#  63: {'genre': {'id': 63, 'name': 'Iyashikei'},
#   'count': 6,
#   'avg_score': 7.333333333333333},
#  36: {'genre': {'id': 36, 'name': 'Slice of Life'},
#   'count': 18,
#   'avg_score': 7.555555555555555},
#  10: {'genre': {'id': 10, 'name': 'Fantasy'},
#   'count': 49,
#   'avg_score': 7.346938775510204},
#  58: {'genre': {'id': 58, 'name': 'Gore'},
#   'count': 11,
#   'avg_score': 8.272727272727273},
#  27: {'genre': {'id': 27, 'name': 'Shounen'}, 'count': 45, 'avg_score': 7.8},
#  31: {'genre': {'id': 31, 'name': 'Super Power'},
#   'count': 13,
#   'avg_score': 7.076923076923077},
#  18: {'genre': {'id': 18, 'name': 'Mecha'},
#   'count': 13,
#   'avg_score': 7.076923076923077},
#  38: {'genre': {'id': 38, 'name': 'Military'},
#   'count': 24,
#   'avg_score': 8.125000000000002},
#  24: {'genre': {'id': 24, 'name': 'Sci-Fi'},
#   'count': 30,
#   'avg_score': 7.566666666666666},
#  2: {'genre': {'id': 2, 'name': 'Adventure'},
#   'count': 33,
#   'avg_score': 7.666666666666667},
#  62: {'genre': {'id': 62, 'name': 'Isekai'},
#   'count': 21,
#   'avg_score': 7.333333333333333},
#  64: {'genre': {'id': 64, 'name': 'Love Polygon'},
#   'count': 4,
#   'avg_score': 5.75},
#  7: {'genre': {'id': 7, 'name': 'Mystery'}, 'count': 14, 'avg_score': 8.5},
#  32: {'genre': {'id': 32, 'name': 'Vampire'}, 'count': 2, 'avg_score': 10.0},
#  53: {'genre': {'id': 53, 'name': 'Childcare'}, 'count': 1, 'avg_score': 7},
#  55: {'genre': {'id': 55, 'name': 'Delinquents'},
#   'count': 2,
#   'avg_score': 8.5},
#  6: {'genre': {'id': 6, 'name': 'Mythology'}, 'count': 4, 'avg_score': 8.0},
#  40: {'genre': {'id': 40, 'name': 'Psychological'},
#   'count': 12,
#   'avg_score': 7.916666666666667},
#  42: {'genre': {'id': 42, 'name': 'Seinen'},
#   'count': 11,
#   'avg_score': 7.181818181818182},
#  78: {'genre': {'id': 78, 'name': 'Time Travel'},
#   'count': 3,
#   'avg_score': 8.0},
#  72: {'genre': {'id': 72, 'name': 'Reincarnation'},
#   'count': 8,
#   'avg_score': 7.0},
#  50: {'genre': {'id': 50, 'name': 'Adult Cast'},
#   'count': 11,
#   'avg_score': 8.363636363636363},
#  29: {'genre': {'id': 29, 'name': 'Space'},
#   'count': 7,
#   'avg_score': 8.285714285714286},
#  41: {'genre': {'id': 41, 'name': 'Suspense'}, 'count': 8, 'avg_score': 8.375},
#  59: {'genre': {'id': 59, 'name': 'High Stakes Game'},
#   'count': 2,
#   'avg_score': 7.0},
#  69: {'genre': {'id': 69, 'name': 'Otaku Culture'},
#   'count': 7,
#   'avg_score': 6.714285714285714},
#  48: {'genre': {'id': 48, 'name': 'Workplace'}, 'count': 2, 'avg_score': 9.5},
#  74: {'genre': {'id': 74, 'name': 'Romantic Subtext'},
#   'count': 2,
#   'avg_score': 7.5},
#  20: {'genre': {'id': 20, 'name': 'Parody'}, 'count': 8, 'avg_score': 7.375},
#  51: {'genre': {'id': 51, 'name': 'Anthropomorphic'},
#   'count': 2,
#   'avg_score': 8.0},
#  11: {'genre': {'id': 11, 'name': 'Strategy Game'},
#   'count': 3,
#   'avg_score': 8.333333333333334},
#  17: {'genre': {'id': 17, 'name': 'Martial Arts'},
#   'count': 4,
#   'avg_score': 8.25},
#  25: {'genre': {'id': 25, 'name': 'Shoujo'}, 'count': 1, 'avg_score': 5},
#  47: {'genre': {'id': 47, 'name': 'Gourmet'}, 'count': 2, 'avg_score': 7.5},
#  14: {'genre': {'id': 14, 'name': 'Horror'}, 'count': 1, 'avg_score': 9},
#  30: {'genre': {'id': 30, 'name': 'Sports'},
#   'count': 3,
#   'avg_score': 8.333333333333334},
#  77: {'genre': {'id': 77, 'name': 'Team Sports'},
#   'count': 3,
#   'avg_score': 8.333333333333334},
#  39: {'genre': {'id': 39, 'name': 'Detective'}, 'count': 1, 'avg_score': 6},
#  79: {'genre': {'id': 79, 'name': 'Video Game'}, 'count': 4, 'avg_score': 5.5},
#  81: {'genre': {'id': 81, 'name': 'Crossdressing'},
#   'count': 1,
#   'avg_score': 6},
#  76: {'genre': {'id': 76, 'name': 'Survival'},
#   'count': 6,
#   'avg_score': 8.666666666666666},
#  5: {'genre': {'id': 5, 'name': 'Avant Garde'}, 'count': 1, 'avg_score': 7},
#  65: {'genre': {'id': 65, 'name': 'Magical Sex Shift'},
#   'count': 1,
#   'avg_score': 7},
#  80: {'genre': {'id': 80, 'name': 'Visual Arts'}, 'count': 1, 'avg_score': 9},
#  19: {'genre': {'id': 19, 'name': 'Music'},
#   'count': 3,
#   'avg_score': 9.666666666666666},
#  21: {'genre': {'id': 21, 'name': 'Samurai'}, 'count': 1, 'avg_score': 7}}

# %%
def get_vintage_preferences(client_id, user, content_type='anime', only_watched=True):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    user         - MAL username that is being analysed
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    only_watched - Set False if all entries (including Dropped and Plan to Watch) are to be analysed
    """
    # get user list and season info
    show_list = {}
    user_animelist = get_user_list_ids(client_id, user, content_type, fields='list_status,start_season')
    season_list = {}
    if only_watched:
        for node in user_animelist['data']:
            if node['list_status']['status'] == "completed":
                if 'start_season' in node['node'].keys():
                    show_list[node['node']['id']] = node['list_status']['score']
                    season_list[node['node']['id']] = node['node']['start_season']
    else:
        for node in user_anilist['data']:
            if 'start_season' in node['node'].keys():
                show_list[node['node']['id']] = node['list_status']['score']
                season_list[node['node']['id']] = node['node']['start_season']
    show_ids = []
    seasons = {}
    # get show ids
    for key in show_list.keys():
        show_ids.append(key)
    # for each season, count number of shows and average rating
    for show in season_list.keys():
        season = str(season_list[show]['year'])+" "+season_list[show]['season']
        if season not in seasons.keys():
            seasons[season] = {'season': season_list[show], 'count' : 1, 'avg_score' : show_list[show]}
        else:
            count = seasons[season]['count'] + 1
            avg_score = (seasons[season]['avg_score'] * (count - 1) + show_list[show]) / count
            seasons[season]['count'] = count
            seasons[season]['avg_score'] = avg_score
    return seasons

# %%
print(get_vintage_preferences(client_id, 'Khalid741'))
# Out:
# {'node': {'id': 38101, 'title': '5-toubun no Hanayome', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1819/97947.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1819/97947l.jpg'}, 'start_season': {'year': 2019, 'season': 'winter'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2021-05-01T10:46:14+00:00'}}
# {'node': {'id': 39783, 'title': '5-toubun no Hanayome ∬', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1775/109514.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1775/109514l.jpg'}, 'start_season': {'year': 2021, 'season': 'winter'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2021-05-06T09:07:13+00:00'}}
# {'node': {'id': 41457, 'title': '86', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1987/117507.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1987/117507l.jpg'}, 'start_season': {'year': 2021, 'season': 'spring'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 11, 'is_rewatching': False, 'updated_at': '2022-01-08T11:37:15+00:00'}}
# {'node': {'id': 48569, 'title': '86 Part 2', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1321/117508.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1321/117508l.jpg'}, 'start_season': {'year': 2021, 'season': 'fall'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2022-04-21T10:57:45+00:00'}}
# {'node': {'id': 22199, 'title': 'Akame ga Kill!', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1429/95946.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1429/95946l.jpg'}, 'start_season': {'year': 2014, 'season': 'summer'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 24, 'is_rewatching': False, 'updated_at': '2017-03-20T02:49:33+00:00'}}
# {'node': {'id': 22729, 'title': 'Aldnoah.Zero', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/7/60263.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/7/60263l.jpg'}, 'start_season': {'year': 2014, 'season': 'summer'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2018-12-08T02:39:56+00:00'}}
# {'node': {'id': 27655, 'title': 'Aldnoah.Zero 2nd Season', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/10/71297.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/10/71297l.jpg'}, 'start_season': {'year': 2015, 'season': 'winter'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 12, 'is_rewatching': False, 'updated_at': '2018-12-08T02:40:15+00:00'}}
# {'node': {'id': 22147, 'title': 'Amagi Brilliant Park', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/5/85435.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/5/85435l.jpg'}, 'start_season': {'year': 2014, 'season': 'fall'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 13, 'is_rewatching': False, 'updated_at': '2021-04-29T08:28:06+00:00'}}
# {'node': {'id': 6547, 'title': 'Angel Beats!', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1244/111115.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/1244/111115l.jpg'}, 'start_season': {'year': 2010, 'season': 'spring'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 13, 'is_rewatching': False, 'updated_at': '2018-11-18T22:45:01+00:00'}}
# {'node': {'id': 24833, 'title': 'Ansatsu Kyoushitsu', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/5/75639.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/5/75639l.jpg'}, 'start_season': {'year': 2015, 'season': 'winter'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 22, 'is_rewatching': False, 'updated_at': '2017-06-17T19:06:51+00:00'}}
# {'node': {'id': 30654, 'title': 'Ansatsu Kyoushitsu 2nd Season', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/8/77966.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/8/77966l.jpg'}, 'start_season': {'year': 2016, 'season': 'winter'}}, 'list_status': {'status': 'completed', 'score': 8, 'num_episodes_watched': 25, 'is_rewatching': False, 'updated_at': '2018-04-20T11:50:48+00:00'}}
# {'node': {'id': 9919, 'title': 'Ao no Exorcist', 'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/10/75195.jpg', 'large': 'https://api-cdn.myanimelist.net/images/anime/10/75195l.jpg'}, 'start_season': {'year': 2011, 'season': 'spring'}}, 'list_status': {'status': 'completed', 'score': 7, 'num_episodes_watched': 25, 'is_rewatching': False, 'updated_at': '
spring': {'season': {'year': 1998, 'season': 'spring'}, 'count': 1, 'avg_score': 6}, '2016 summer': {'season': {'year': 2016, 'season': 'summer'}, 'count': 7, 'avg_score': 7.285714285714286}, '2007 spring': {'season': {'year': 2007, 'season': 'spring'}, 'count': 1, 'avg_score': 7}, '2010 winter': {'season': {'year': 2010, 'season': 'winter'}, 'count': 1, 'avg_score': 6}, '2009 fall': {'season': {'year': 2009, 'season': 'fall'}, 'count': 1, 'avg_score': 5}, '2018 winter': {'season': {'year': 2018, 'season': 'winter'}, 'count': 6, 'avg_score': 8.0}, '2020 summer': {'season': {'year': 2020, 'season': 'summer'}, 'count': 2, 'avg_score': 8.0}, '2020 fall': {'season': {'year': 2020, 'season': 'fall'}, 'count': 5, 'avg_score': 8.4}, '2013 spring': {'season': {'year': 2013, 'season': 'spring'}, 'count': 5, 'avg_score': 7.0}, '2013 fall': {'season': {'year': 2013, 'season': 'fall'}, 'count': 5, 'avg_score': 7.6}, '2009 spring': {'season': {'year': 2009, 'season': 'spring'}, 'count': 3, 'avg_score': 7.0}, '2016 fall': {'season': {'year': 2016, 'season': 'fall'}, 'count': 2, 'avg_score': 8.5}, '2019 fall': {'season': {'year': 2019, 'season': 'fall'}, 'count': 2, 'avg_score': 8.0}, '2006 winter': {'season': {'year': 2006, 'season': 'winter'}, 'count': 1, 'avg_score': 7}, '2012 spring': {'season': {'year': 2 ...

# %%
def get_related_shows(client_id, show_ids, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_ids     - List of show ids to check
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """
    # If only checking 1 show, puts single show into list wrapper
    if type(show_ids) == int:
        show_ids = [show_ids]
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    franchises = {}
    # HTTP GET each show's related series
    for show in show_ids:
        url = base_url + content + "/" + str(show) + "?fields=related_" + content
        r = requests.get(url, headers=auth_header)
        if show not in franchises:
            franchises[show] = r.json()['related_'+content]
    for show in franchises.keys():
        rel_list = []
        for node in franchises[show]:
            rel_list.append(node['node']['id'])
        franchises[show] = rel_list
    return franchises

# %%
get_related_shows(client_id, get_show_id(client_id, "Bakemonogatari"))
# Out:
# {5081: [6948, 11597, 15689, 30514, 32268]}

# %%
def get_show_pictures(client_id, show_ids, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_ids     - List of show ids to check
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """
    # If only checking 1 show, puts single show into list wrapper
    if type(show_ids) == int:
        show_ids = [show_ids]
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    images = {}
    # HTTP GET each show's related series
    for show in show_ids:
        url = base_url + content + "/" + str(show)
        r = requests.get(url, headers=auth_header)
        images[show] = r.json()['main_picture']
    return images

# %%
get_show_pictures(client_id, 1)
# Out:
# {1: {'medium': 'https://api-cdn.myanimelist.net/images/anime/4/19644.jpg',
#   'large': 'https://api-cdn.myanimelist.net/images/anime/4/19644l.jpg'}}

# %%
def get_show_studio(client_id, show_ids, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_ids     - List of show ids to check
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """
    # If only checking 1 show, puts single show into list wrapper
    if type(show_ids) == int:
        show_ids = [show_ids]
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    studios = {}
    # HTTP GET each show's Production Studios
    for show in show_ids:
        url = base_url + content + "/" + str(show)
        r = requests.get(url, headers=auth_header, params={'fields':'studios'})
        studios[show] = r.json()['studios']
    return studios

# %%
get_show_studio(client_id, 1)
# Out:
# {1: [{'id': 14, 'name': 'Sunrise'}]}

# %%
def get_preference(client_id, user, field, content_type='anime', only_watched=True):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    user         - MAL username that is being analysed
    field        - string for field that is wanted
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    only_watched - Set False if all entries (including Dropped and Plan to Watch) are to be analysed
    """
    # get user list and season info
    show_list = {}
    user_animelist = get_user_list_ids(client_id, user, content_type, fields='list_status,'+field)
    field_list = {}
    if only_watched:
        for node in user_animelist['data']:
            if node['list_status']['status'] == "completed":
                show_list[node['node']['id']] = node['list_status']['score']
                field_list[node['node']['id']] = node['node'][field]
    else:
        for node in user_anilist['data']:
            show_list[node['node']['id']] = node['list_status']['score']
            field_list[node['node']['id']] = node['node'][field]
    show_ids = []
    fields = {}
    # get show ids
    for key in show_list.keys():
        show_ids.append(key)
    # iterate through genres to get count of number of shows with each genre tag and average user score
    for show in field_list.keys():
        for field_ in field_list[show]:
            if field_['id'] not in fields.keys():
                fields[field_['id']] = {field : field_, 'count' : 1, 'avg_score' : show_list[show]}
            else:
                count = fields[field_['id']]['count'] + 1
                avg_score = (fields[field_['id']]['avg_score'] * (count - 1) + show_list[show]) / count
                fields[field_['id']]['count'] = count
                fields[field_['id']]['avg_score'] = avg_score
    return_field = []
    for field in fields.keys():
        return_field.append(fields[field])
    return return_field

# %%
get_preference(client_id, 'turtlemage', 'studios')
# Out:
# [{'studios': {'id': 1119, 'name': 'Shuka'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 441, 'name': '8bit'}, 'count': 4, 'avg_score': 6.25},
#  {'studios': {'id': 48, 'name': 'AIC'}, 'count': 1, 'avg_score': 10},
#  {'studios': {'id': 314, 'name': 'White Fox'}, 'count': 6, 'avg_score': 8.0},
#  {'studios': {'id': 56, 'name': 'A-1 Pictures'},
#   'count': 11,
#   'avg_score': 6.2727272727272725},
#  {'studios': {'id': 1103, 'name': 'TROYCA'}, 'count': 1, 'avg_score': 6},
#  {'studios': {'id': 163, 'name': 'asread.'},
#   'count': 3,
#   'avg_score': 5.666666666666667},
#  {'studios': {'id': 537, 'name': 'SANZIGEN'}, 'count': 1, 'avg_score': 7},
#  {'studios': {'id': 839, 'name': 'LIDENFILMS'},
#   'count': 3,
#   'avg_score': 7.333333333333333},
#  {'studios': {'id': 300, 'name': 'SILVER LINK.'},
#   'count': 8,
#   'avg_score': 6.625},
#  {'studios': {'id': 44, 'name': 'Shaft'}, 'count': 6, 'avg_score': 8.5},
#  {'studios': {'id': 1129, 'name': 'Pierrot Plus'},
#   'count': 2,
#   'avg_score': 7.0},
#  {'studios': {'id': 1873, 'name': 'Silver'}, 'count': 2, 'avg_score': 7.5},
#  {'studios': {'id': 1874, 'name': 'Arvo Animation'},
#   'count': 2,
#   'avg_score': 7.5},
#  {'studios': {'id': 291, 'name': 'CoMix Wave Films'},
#   'count': 1,
#   'avg_score': 2},
#  {'studios': {'id': 1264, 'name': 'EMT Squared'},
#   'count': 2,
#   'avg_score': 6.0},
#  {'studios': {'id': 2, 'name': 'Kyoto Animation'},
#   'count': 3,
#   'avg_score': 9.0},
#  {'studios': {'id': 14, 'name': 'Sunrise'},
#   'count': 7,
#   'avg_score': 8.571428571428571},
#  {'studios': {'id': 4, 'name': 'Bones'}, 'count': 3, 'avg_score': 8.0},
#  {'studios': {'id': 292, 'name': 'AIC PLUS+'}, 'count': 1, 'avg_score': 4},
#  {'studios': {'id': 957, 'name': 'Connect'}, 'count': 1, 'avg_score': 6},
#  {'studios': {'id': 11, 'name': 'Madhouse'},
#   'count': 11,
#   'avg_score': 7.818181818181818},
#  {'studios': {'id': 218, 'name': 'Zexcs'}, 'count': 1, 'avg_score': 8},
#  {'studios': {'id': 7, 'name': 'J.C.Staff'},
#   'count': 12,
#   'avg_score': 7.166666666666667},
#  {'studios': {'id': 112, 'name': "Brain's Base"},
#   'count': 2,
#   'avg_score': 4.5},
#  {'studios': {'id': 397, 'name': 'Bridge'}, 'count': 1, 'avg_score': 6},
#  {'studios': {'id': 207, 'name': 'Magic Bus'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 2256, 'name': 'Kitty Film Mitaka Studio'},
#   'count': 2,
#   'avg_score': 8.5},
#  {'studios': {'id': 95, 'name': 'Doga Kobo'}, 'count': 1, 'avg_score': 8},
#  {'studios': {'id': 1, 'name': 'Studio Pierrot'},
#   'count': 2,
#   'avg_score': 8.5},
#  {'studios': {'id': 10, 'name': 'Production I.G'},
#   'count': 5,
#   'avg_score': 7.8},
#  {'studios': {'id': 27, 'name': 'Xebec'},
#   'count': 3,
#   'avg_score': 6.333333333333333},
#  {'studios': {'id': 1974, 'name': 'ENGI'}, 'count': 1, 'avg_score': 6},
#  {'studios': {'id': 37, 'name': 'Studio Deen'},
#   'count': 3,
#   'avg_score': 8.333333333333334},
#  {'studios': {'id': 18, 'name': 'Toei Animation'},
#   'count': 2,
#   'avg_score': 9.0},
#  {'studios': {'id': 1835, 'name': 'CloverWorks'}, 'count': 1, 'avg_score': 10},
#  {'studios': {'id': 21, 'name': 'Studio Ghibli'},
#   'count': 6,
#   'avg_score': 8.833333333333334},
#  {'studios': {'id': 569, 'name': 'MAPPA'}, 'count': 4, 'avg_score': 7.25},
#  {'studios': {'id': 30, 'name': 'Ajia-Do'}, 'count': 1, 'avg_score': 5},
#  {'studios': {'id': 196, 'name': 'Production Reed'},
#   'count': 1,
#   'avg_score': 7},
#  {'studios': {'id': 309, 'name': 'GoHands'}, 'count': 1, 'avg_score': 7},
#  {'studios': {'id': 32, 'name': 'Manglobe'}, 'count': 3, 'avg_score': 8.0},
#  {'studios': {'id': 1978, 'name': 'Maho Film'}, 'count': 1, 'avg_score': 7},
#  {'studios': {'id': 346, 'name': 'Hoods Entertainment'},
#   'count': 1,
#   'avg_score': 8},
#  {'studios': {'id': 3, 'name': 'Gonzo'}, 'count': 1, 'avg_score': 10},
#  {'studios': {'id': 28, 'name': 'OLM'}, 'count': 2, 'avg_score': 9.0},
#  {'studios': {'id': 101, 'name': 'Studio Hibari'}, 'count': 1, 'avg_score': 8},
#  {'studios': {'id': 43, 'name': 'ufotable'}, 'count': 1, 'avg_score': 8},
#  {'studios': {'id': 41, 'name': 'Satelight'}, 'count': 2, 'avg_score': 7.0},
#  {'studios': {'id': 456, 'name': 'Lerche'}, 'count': 2, 'avg_score': 6.5},
#  {'studios': {'id': 1794, 'name': 'EKACHI EPILKA'},
#   'count': 1,
#   'avg_score': 8},
#  {'studios': {'id': 38, 'name': 'Arms'}, 'count': 1, 'avg_score': 8},
#  {'studios': {'id': 91, 'name': 'feel.'},
#   'count': 3,
#   'avg_score': 6.333333333333333},
#  {'studios': {'id': 51, 'name': 'Diomedéa'}, 'count': 2, 'avg_score': 9.5},
#  {'studios': {'id': 103, 'name': 'Tatsunoko Production'},
#   'count': 2,
#   'avg_score': 8.5},
#  {'studios': {'id': 1993, 'name': 'Studio Bind'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 6, 'name': 'Gainax'}, 'count': 2, 'avg_score': 8.0},
#  {'studios': {'id': 439, 'name': 'Project No.9'},
#   'count': 2,
#   'avg_score': 8.0},
#  {'studios': {'id': 436, 'name': 'AIC Build'}, 'count': 1, 'avg_score': 4},
#  {'studios': {'id': 1857, 'name': 'GEEK TOYS'}, 'count': 1, 'avg_score': 6},
#  {'studios': {'id': 1379, 'name': 'Zero-G'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 1444, 'name': 'Egg Firm'}, 'count': 2, 'avg_score': 7.5},
#  {'studios': {'id': 858, 'name': 'Wit Studio'}, 'count': 4, 'avg_score': 9.0},
#  {'studios': {'id': 290, 'name': 'Kinema Citrus'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 1687, 'name': 'Yokohama Animation Lab'},
#   'count': 1,
#   'avg_score': 9},
#  {'studios': {'id': 1569, 'name': 'Seven Arcs Pictures'},
#   'count': 1,
#   'avg_score': 9},
#  {'studios': {'id': 418, 'name': 'Studio Gokumi'}, 'count': 1, 'avg_score': 9},
#  {'studios': {'id': 1591, 'name': 'Science SARU'},
#   'count': 1,
#   'avg_score': 10},
#  {'studios': {'id': 1567, 'name': 'Nut'}, 'count': 1, 'avg_score': 7}]

# %%
def get_top_shows(client_id, numShows, content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    numShows     - number of shows (from the top) to return
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """ 
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    # Until numShows is reached, HTTP GET more
    if numShows < 500:
        iteration = numShows
    else:
        iteration = 500
    url = base_url + content + '/ranking?ranking_type=all&limit=' + str(iteration)
    r = requests.get(url, headers=auth_header)
    show_list = []
    i = 0
    while i < numShows:
        for node in r.json()['data']:
            if i < numShows:
                show_list.append(node['node']['id'])
                i = i + 1
        if i < numShows:
            r = requests.get(r.json()['paging']['next'], headers=auth_header)
    return show_list

# %%
topshows = get_top_shows(client_id, 200)

# %%
get_show_stats(client_id, show_ids=get_top_shows(client_id, 50), stat='studios')
# Out:
# [[{'id': 4, 'name': 'Bones'}],
#  [{'id': 1258, 'name': 'Bandai Namco Pictures'}],
#  [{'id': 858, 'name': 'Wit Studio'}],
#  [{'id': 858, 'name': 'Wit Studio'}, {'id': 1835, 'name': 'CloverWorks'}],
#  [{'id': 314, 'name': 'White Fox'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 1258, 'name': 'Bandai Namco Pictures'}],
#  [{'id': 11, 'name': 'Madhouse'}],
#  [{'id': 73, 'name': 'TMS Entertainment'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 1269, 'name': 'K-Factory'},
#   {'id': 2256, 'name': 'Kitty Film Mitaka Studio'}],
#  [{'id': 1258, 'name': 'Bandai Namco Pictures'}],
#  [{'id': 44, 'name': 'Shaft'}],
#  [{'id': 56, 'name': 'A-1 Pictures'}],
#  [{'id': 2, 'name': 'Kyoto Animation'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 2, 'name': 'Kyoto Animation'}],
#  [{'id': 2, 'name': 'Kyoto Animation'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 44, 'name': 'Shaft'}],
#  [{'id': 569, 'name': 'MAPPA'}],
#  [{'id': 43, 'name': 'ufotable'}],
#  [{'id': 1258, 'name': 'Bandai Namco Pictures'}],
#  [{'id': 291, 'name': 'CoMix Wave Films'}],
#  [{'id': 569, 'name': 'MAPPA'}],
#  [{'id': 11, 'name': 'Madhouse'}],
#  [{'id': 4, 'name': 'Bones'}],
#  [{'id': 1258, 'name': 'Bandai Namco Pictures'}],
#  [{'id': 44, 'name': 'Shaft'}],
#  [{'id': 1774, 'name': 'Studio LAN'}],
#  [{'id': 21, 'name': 'Studio Ghibli'}],
#  [{'id': 10, 'name': 'Production I.G'}],
#  [{'id': 1129, 'name': 'Pierrot Plus'},
#   {'id': 1998, 'name': 'Studio Signpost'}],
#  [{'id': 44, 'name': 'Shaft'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  [{'id': 1993, 'name': 'Studio Bind'}],
#  [{'id': 28, 'name': 'OLM'}, {'id': 1872, 'name': 'P.I.C.S.'}],
#  [{'id': 37, 'name': 'Studio Deen'}],
#  [{'id': 8, 'name': 'Artland'}],
#  [{'id': 11, 'name': 'Madhouse'}],
#  [{'id': 858, 'name': 'Wit Studio'}],
#  [{'id': 56, 'name': 'A-1 Pictures'}],
#  [{'id': 43, 'name': 'ufotable'}],
#  [{'id': 65, 'name': 'Tokyo Movie Shinsha'}],
#  [{'id': 8, 'name': 'Artland'}],
#  [{'id': 37, 'name': 'Studio Deen'}],
#  [{'id': 1350, 'name': 'B.CMAY PICTURES'}],
#  [{'id': 14, 'name': 'Sunrise'}],
#  []]

# %%
def get_top_shows_stat(client_id, show_num, stat='', content_type='anime'):
    """
    Parameters:
    
    client_id    - Client ID generated by MyAnimeList app ("www.myanimelist.net/apiconfig/")
    show_num     - number of shows (from the top) to return
    stat         - statistic to get
    content_type - anime or manga, to decide whether to find animelist or mangalist respectively
    """ 
    # Define Content Type for url definition
    if content_type == 'anime':
        content = 'anime'
    else:
        content = 'manga'
    # Creating Authentication header for HTTP GET
    auth_header = {'X-MAL-CLIENT-ID' : client_id}
    base_url = "https://api.myanimelist.net/v2/"
    # Until numShows is reached, HTTP GET more
    if show_num < 500:
        iteration = show_num
    else:
        iteration = 500
    url = base_url + content + '/ranking?ranking_type=all&limit=' + str(iteration) + "&fields=" + stat
    r = requests.get(url, headers=auth_header)
    show_list = []
    i = 0
    while i < show_num:
        for node in r.json()['data']:
            if i < show_num:
                show_list.append(node['node'])
                i = i + 1
        if i < show_num:
            r = requests.get(r.json()['paging']['next'], headers=auth_header)
    return show_list

# %%
top_shows = get_top_shows_stat(client_id, 10000, stat='start_season')
i = 1
for show in top_shows:
    print(str(i) + " " + str(show['id']) + " : " +str(show['start_season']))
    i = i+1
# Out:
# 1 5114 : {'year': 2009, 'season': 'spring'}
# 2 28977 : {'year': 2015, 'season': 'spring'}
# 3 38524 : {'year': 2019, 'season': 'spring'}
# 4 50265 : {'year': 2022, 'season': 'spring'}
# 5 9253 : {'year': 2011, 'season': 'spring'}
# 6 9969 : {'year': 2011, 'season': 'spring'}
# 7 39486 : {'year': 2021, 'season': 'winter'}
# 8 11061 : {'year': 2011, 'season': 'fall'}
# 9 42938 : {'year': 2021, 'season': 'spring'}
# 10 15417 : {'year': 2012, 'season': 'fall'}
# 11 820 : {'year': 1988, 'season': 'winter'}
# 12 34096 : {'year': 2017, 'season': 'winter'}
# 13 35180 : {'year': 2017, 'season': 'fall'}
# 14 43608 : {'year': 2022, 'season': 'spring'}
# 15 28851 : {'year': 2016, 'season': 'summer'}
# 16 918 : {'year': 2006, 'season': 'spring'}
# 17 37987 : {'year': 2020, 'season': 'summer'}
# 18 4181 : {'year': 2008, 'season': 'fall'}
# 19 15335 : {'year': 2013, 'season': 'summer'}
# 20 2904 : {'year': 2008, 'season': 'spring'}
# 21 35247 : {'year': 2017, 'season': 'summer'}
# 22 48583 : {'year': 2022, 'season': 'winter'}
# 23 47778 : {'year': 2022, 'season': 'winter'}
# 24 37491 : {'year': 2018, 'season': 'summer'}
# 25 32281 : {'year': 2016, 'season': 'summer'}
# 26 40028 : {'year': 2021, 'season': 'winter'}
# 27 19 : {'year': 2004, 'season': 'spring'}
# 28 37510 : {'year': 2019, 'season': 'winter'}
# 29 36838 : {'year': 2018, 'season': 'winter'}
# 30 31758 : {'year': 2017, 'season': 'winter'}
# 31 44074 : {'year': 2021, 'season': 'spring'}
# 32 199 : {'year': 2001, 'season': 'summer'}
# 33 32935 : {'year': 2016, 'season': 'fall'}
# 34 40682 : {'year': 2020, 'season': 'spring'}
# 35 17074 : {'year': 2013, 'season': 'summer'}
# 36 1 : {'year': 1998, 'season': 'spring'}
# 37 45576 : {'year': 2021, 'season': 'fall'}
# 38 46102 : {'year': 2021, 'season': 'spring'}
# 39 33095 : {'year': 2017, 'season': 'winter'}
# 40 24701 : {'year': 2014, 'season': 'fall'}
# 41 263 : {'year': 2000, 'season': 'fall'}
# 42 37521 : {'year': 2019, 'season': 'summer'}
# 43 48569 : {'year': 2021, 'season': 'fall'}
# 44 33050 : {'year': 2020, 'season': 'summer'}
# 45 2921 : {'year': 1980, 'season': 'fall'}
# 46 21939 : {'year': 2014, 'season': 'spring'}
# 47 44 : {'year': 1999, 'season': 'winter'}
# 48 40434 : {'year': 2021, 'season': 'summer'}
# 49 1575 : {'year': 2006, 'season': 'fall'}
# 50 50160 : {'year': 2022, 'season': 'spring'}
# 51 245 : {'year': 1999, 'season': 'summer'}
# 52 40748 : {'year': 2020, 'season': 'fall'}
# 53 34599 : {'year': 2017, 'season': 'summer'}
# 54 36862 : {'year': 2020, 'season': 'winter'}
# 55 164 : {'year': 1997, 'season': 'summer'}
# 56 457 : {'year': 2005, 'season': 'fall'}
# 57 40834 : {'year': 2021, 'season': 'fall'}
# 58 23273 : {'year': 2014, 'season': 'fall'}
# 59 33352 : {'year': 2018, 'season': 'winter'}
# 60 40456 : {'year': 2020, 'season': 'fall'}
# 61 5258 : {'year': 2009, 'season': 'winter'}
# 62 431 : {'year': 2004, 'season': 'fall'}
# 63 3786 : {'year': 2021, 'season': 'winter'}
# 64 28891 : {'year': 2015, 'season': 'fall'}
# 65 40591 : {'year': 2020, 'season': 'spring'}
# 66 11665 : {'year': 2012, 'season': 'winter'}
# 67 2001 : {'year': 2007, 'season': 'spring'}
# 68 34591 : {'year': 2017, 'season': 'spring'}
# 69 21 : {'year': 1999, 'season': 'fall'}
# 70 1535 : {'year': 2006, 'season': 'fall'}
# 71 22135 : {'year': 2014, 'season': 'spring'}
# 72 38329 : {'year': 2019, 'season': 'spring'}
# 73 35760 : {'year': 2018, 'season': 'summer'}
# 74 7311 : {'year': 2010, 'season': 'winter'}
# 75 28957 : {'year': 2015, 'season': 'spring'}
# 76 12355 : {'year': 2012, 'season': 'summer'}
# 77 31757 : {'year': 2016, 'season': 'summer'}
# 78 19647 : {'year': 2013, 'season': 'fall'}
# 79 37991 : {'year': 2018, 'season': 'fall'}
# 80 32983 : {'year': 2016, 'season': 'fall'}
# 81 10379 : {'year': 2011, 'season': 'summer'}
# 82 40664 : {'year': 2021, 'season': 'spring'}
# 83 28735 : {'year': 2016, 'season': 'winter'}
# 84 7785 : {'year': 2010, 'season': 'spring'}
# 85 4565 : {'year': 2009, 'season': 'spring'}
# 86 11741 : {'year': 2012, 'season': 'spring'}
# 87 40417 : {'year': 2020, 'season': 'spring'}
# 88 36098 : {'year': 2018, 'season': 'summer'}
# 89 12365 : {'year': 2012, 'season': 'fall'}
# 90 38000 : {'year': 2019, 'season': 'spring'}
# 91 21329 : {'year': 2014, 'season': 'winter'}
# 92 32 : {'year': 1997, 'season': 'summer'}
# 93 37779 : {'year': 2019, 'season': 'winter'}
# 94 5300 : {'year': 2009, 'season': 'winter'}
# 95 35839 : {'year': 2018, 'season': 'winter'}
# 96 38474 : {'year': 2021, 'season': 'winter'}
# 97 40776 : {'year': 2020, 'season': 'fall'}
# 98 4282 : {'year': 2008, 'season': 'summer'}
# 99 33049 : {'year': 2019, 'season': 'winter'}
# 100 35843 : {'year': 2017, 'season': 'fall'}
# 101 48561 : {'year': 2021, 'season': 'fall'}
# 102 33 : {'year': 1997, 'season': 'fall'}
# 103 16498 : {'year': 2013, 'season': 'spring'}
# 104 170 : {'year': 1993, 'season': 'fall'}
# 105 437 : {'year': 1998, 'season': 'winter'}
# 106 30484 : {'year': 2018, 'season': 'spring'}
# 107 7472 : {'year': 2010, 'season': 'spring'}
# 108 801 : {'year': 2004, 'season': 'winter'}
# 109 30654 : {'year': 2016, 'season': 'winter'}
# 110 36649 : {'year': 2018, 'season': 'summer'}
# 111 578 : {'year': 1988, 'season': 'spring'}
# 112 49721 : {'year': 2022, 'season': 'winter'}
# 113 877 : {'year': 2006, 'season': 'spring'}
# 114 30276 : {'year': 2015, 'season': 'fall'}
# 115 12431 : {'year': 2012, 'season': 'spring'}
# 116 205 : {'year': 2004, 'season': 'spring'}
# 117 25777 : {'year': 2017, 'season': 'spring'}
# 118 44070 : {'year': 2021, 'season': 'winter'}
# 119 3297 : {'year': 2008, 'season': 'winter'}
# 120 31933 : {'year': 2016, 'season': 'spring'}
# 121 6114 : {'year': 2010, 'season': 'spring'}
# 122 42203 : {'year': 2021, 'season': 'winter'}
# 123 32182 : {'year': 2016, 'season': 'summer'}
# 124 37379 : {'year': 2019, 'season': 'fall'}
# 125 44087 : {'year': 2021, 'season': 'winter'}
# 126 38040 : {'year': 2019, 'season': 'summer'}
# 127 37208 : {'year': 2018, 'season': 'summer'}
# 128 10165 : {'year': 2011, 'season': 'spring'}
# 129 31181 : {'year': 2015, 'season': 'fall'}
# 130 36885 : {'year': 2019, 'season': 'fall'}
# 131 11577 : {'year': 2013, 'season': 'spring'}
# 132 36999 : {'year': 2018, 'season': 'fall'}
# 133 40787 : {'year': 2020, 'season': 'fall'}
# 134 11981 : {'year': 2013, 'season': 'fall'}
# 135 40059 : {'year': 2020, 'season': 'fall'}
# 136 20583 : {'year': 2014, 'season': 'spring'}
# 137 38450 : {'year': 2019, 'season': 'summer'}
# 138 46095 : {'year': 2021, 'season': 'spring'}
# 139 392 : {'year': 1992, 'season': 'fall'}
# 140 24687 : {'year': 2014, 'season': 'summer'}
# 141 34612 : {'year': 2018, 'season': 'winter'}
# 142 45556 : {'year': 2021, 'season': 'winter'}
# 143 21899 : {'year': 2012, 'season': 'summer'}
# 144 26055 : {'year': 2015, 'season': 'winter'}
# 145 37105 : {'year': 2018, 'season': 'summer'}
# 146 48661 : {'year': 2021, 'season': 'fall'}
# 147 38889 : {'year': 2019, 'season': 'fall'}
# 148 467 : {'year': 2002, 'season': 'fall'}
# 149 2246 : {'year': 2007, 'season': 'summer'}
# 150 33255 : {'year': 2016, 'season': 'summer'}
# 151 5028 : {'year': 2009, 'season': 'winter'}
# 152 48653 : {'year': 2019, 'season': 'fall'}
# 153 49310 : {'year': 2022, 'season': 'winter'}
# 154 5205 : {'year': 2009, 'season': 'summer'}
# 155 37965 : {'year': 2018, 'season': 'fall'}
# 156 36538 : {'year': 2018, 'season': 'summer'}
# 157 35851 : {'year': 2018, 'season': 'winter'}
# 158 25781 : {'year': 2014, 'season': 'fall'}
# 159 48736 : {'year': 2022, 'season': 'winter'}
# 160 39741 : {'year': 2019, 'season': 'summer'}
# 161 36275 : {'year': 2017, 'season': 'summer'}
# 162 39808 : {'year': 2021, 'season': 'winter'}
# 163 39551 : {'year': 2021, 'season': 'winter'}
# 164 31646 : {'year': 2016, 'season': 'fall'}
# 165 14397 : {'year': 2013, 'season': 'winter'}
# 166 5941 : {'year': 2009, 'season': 'spring'}
# 167 32366 : {'year': 2016, 'season': 'summer'}
# 168 35557 : {'year': 2017, 'season': 'fall'}
# 169 136 : {'year': 1999, 'season': 'fall'}
# 170 37999 : {'year': 2019, 'season': 'winter'}
# 171 22789 : {'year': 2014, 'season': 'summer'}
# 172 41025 : {'year': 2021, 'season': 'spring'}
# 173 49926 : {'year': 2021, 'season': 'fall'}
# 174 39247 : {'year': 2021, 'season': 'summer'}
# 175 40730 : {'year': 2020, 'season': 'fall'}
# 176 39547 : {'year': 2020, 'season': 'summer'}
# 177 10162 : {'year': 2011, 'season': 'summer'}
# 178 2251 : {'year': 2007, 'season': 'summer'}
# 179 5 : {'year': 2001, 'season': 'summer'}
# 180 44042 : {'year': 2019, 'season': 'spring'}
# 181 30709 : {'year': 2015, 'season': 'summer'}
# 182 9260 : {'year': 2016, 'season': 'winter'}
# 183 49909 : {'year': 2022, 'season': 'winter'}
# 184 11979 : {'year': 2012, 'season': 'fall'}
# 185 572 : {'year': 1984, 'season': 'winter'}
# 186 39535 : {'year': 2021, 'season': 'winter'}
# 187 39587 : {'year': 2020, 'season': 'summer'}
# 188 50380 : {'year': 2022, 'season': 'spring'}
# 189 10030 : {'year': 2011, 'season': 'fall'}
# 190 38883 : {'year': 2020, 'season': 'winter'}
# 191 777 : {'year': 2006, 'season': 'winter'}
# 192 17389 : {'year': 2013, 'season': 'summer'}
# 193 9756 : {'year': 2011, 'season': 'winter'}
# 194 6945 : {'year': 2008, 'season': 'summer'}
# 195 39533 : {'year': 2019, 'season': 'summer'}
# 196 22535 : {'year': 2014, 'season': 'fall'}
# 197 37515 : {'year': 2019, 'season': 'winter'}
# 198 13601 : {'year': 2012, 'season': 'fall'}
# 199 7655 : {'year': 2010, 'season': 'spring'}
# 200 20651 : {'year': 2014, 'season': 'winter'}
# 201 30 : {'year': 1995, 'season': 'fall'}
# 202 5040 : {'year': 2008, 'season': 'fall'}
# 203 12029 : {'year': 2012, 'season': 'spring'}
# 204 338 : {'year': 1979, 'season': 'fall'}
# 205 9989 : {'year': 2011, 'season': 'spring'}
# 206 5081 : {'year': 2009, 'season': 'summer'}
# 207 49701 : {'year': 2021, 'season': 'fall'}
# 208 42984 : {'year': 2020, 'season': 'summer'}
# 209 9617 : {'year': 2011, 'season': 'fall'}
# 210 6594 : {'year': 2010, 'season': 'winter'}
# 211 5420 : {'year': 2009, 'season': 'winter'}
# 212 10937 : {'year': 2015, 'season': 'winter'}
# 213 5341 : {'year': 2009, 'season': 'summer'}
# 214 2559 : {'year': 1995, 'season': 'winter'}
# 215 4081 : {'year': 2008, 'season': 'summer'}
# 216 34534 : {'year': 2017, 'season': 'winter'}
# 217 1210 : {'year': 2006, 'season': 'summer'}
# 218 12531 : {'year': 2012, 'season': 'spring'}
# 219 38826 : {'year': 2019, 'season': 'summer'}
# 220 37095 : {'year': 2018, 'season': 'summer'}
# 221 44940 : {'year': 2021, 'season': 'fall'}
# 222 31043 : {'year': 2016, 'season': 'winter'}
# 223 3784 : {'year': 2009, 'season': 'summer'}
# 224 28701 : {'year': 2015, 'season': 'spring'}
# 225 39112 : {'year': 2019, 'season': 'winter'}
# 226 50631 : {'year': 2022, 'season': 'spring'}
# 227 30346 : {'year': 2016, 'season': 'winter'}
# 228 10408 : {'year': 2011, 'season': 'summer'}
# 229 137 : {'year': 2002, 'season': 'winter'}
# 230 185 : {'year': 1998, 'season': 'spring'}
# 231 24415 : {'year': 2015, 'season': 'winter'}
# 232 11917 : {'year': 2011, 'season': 'fall'}
# 233 34240 : {'year': 2016, 'season': 'fall'}
# 234 13125 : {'year': 2012, 'season': 'fall'}
# 235 41487 : {'year': 2021, 'season': 'summer'}
# 236 45 : {'year': 1996, 'season': 'winter'}
# 237 25835 : {'year': 2014, 'season': 'fall'}
# 238 10863 : {'year': 2012, 'season': 'winter'}
# 239 57 : {'year': 2004, 'season': 'fall'}
# 240 1365 : {'year': 2002, 'season': 'spring'}
# 241 30230 : {'year': 2015, 'season': 'spring'}
# 242 38691 : {'year': 2019, 'season': 'summer'}
# 243 10087 : {'year': 2011, 'season': 'fall'}
# 244 31988 : {'year': 2016, 'season': 'fall'}
# 245 486 : {'year': 2003, 'season': 'spring'}
# 246 2402 : {'year': 1970, 'season': 'spring'}
# 247 9735 : {'year': 2010, 'season': 'fall'}
# 248 2685 : {'year': 2007, 'season': 'fall'}
# 249 1698 : {'year': 2007, 'season': 'winter'}
# 250 6675 : {'year': 2009, 'season': 'summer'}
# 251 44055 : {'year': 2022, 'season': 'winter'}
# 252 37450 : {'year': 2018, 'season': 'fall'}
# 253 2418 : {'year': 2007, 'season': 'summer'}
# 254 759 : {'year': 2003, 'season': 'fall'}
# 255 28805 : {'year': 2015, 'season': 'summer'}
# 256 19363 : {'year': 2014, 'season': 'winter'}
# 257 3002 : {'year': 2007, 'season': 'fall'}
# 258 32937 : {'year': 2017, 'season': 'winter'}
# 259 43 : {'year': 1995, 'season': 'fall'}
# 260 40052 : {'year': 2020, 'season': 'summer'}
# 261 264 : {'year': 2003, 'season': 'spring'}
# 262 329 : {'year': 2003, 'season': 'fall'}
# 263 513 : {'year': 1986, 'season': 'summer'}
# 264 34798 : {'year': 2018, 'season': 'winter'}
# 265 36990 : {'year': 2018, 'season': 'summer'}
# 266 23327 : {'year': 2014, 'season': 'summer'}
# 267 523 : {'year': 1988, 'season': 'spring'}
# 268 139 : {'year': 2004, 'season': 'winter'}
# 269 22507 : {'year': 2014, 'season': 'spring'}
# 270 11843 : {'year': 2012, 'season': 'winter'}
# 271 38731 : {'year': 2019, 'season': 'spring'}
# 272 10271 : {'year': 2011, 'season': 'spring'}
# 273 31812 : {'year': 2017, 'season': 'winter'}
# 274 31240 : {'year': 2016, 'season': 'spring'}
# 275 1033 : {'year': 2002, 'season': 'summer'}
# 276 47194 : {'year': 2022, 'season': 'spring'}
# 277 40784 : {'year': 2019, 'season': 'fall'}
# 278 1842 : {'year': 2007, 'season': 'winter'}
# 279 1735 : {'year': 2007, 'season': 'winter'}
# 280 5690 : {'year': 2010, 'season': 'winter'}
# 281 38234 : {'year': 2019, 'season': 'summer'}
# 282 2966 : {'year': 2008, 'season': 'winter'}
# 283 37078 : {'year': 2018, 'season': 'spring'}
# 284 32188 : {'year': 2015, 'season': 'fall'}
# 285 37055 : {'year': 2019, 'season': 'winter'}
# 286 42498 : {'year': 2020, 'season': 'spring'}
# 287 41457 : {'year': 2021, 'season': 'spring'}
# 288 34036 : {'year': 2016, 'season': 'fall'}
# 289 37520 : {'year': 2019, 'season': 'winter'}
# 290 37989 : {'year': 2018, 'season': 'fall'}
# 291 265 : {'year': 2003, 'season': 'summer'}
# 292 16894 : {'year': 2013, 'season': 'fall'}
# 293 40211 : {'year': 2019, 'season': 'summer'}
# 294 18115 : {'year': 2013, 'season': 'fall'}
# 295 627 : {'year': 2004, 'season': 'fall'}
# 296 33051 : {'year': 2016, 'season': 'fall'}
# 297 9863 : {'year': 2011, 'season': 'spring'}
# 298 23847 : {'year': 2015, 'season': 'spring'}
# 299 43325 : {'year': 2021, 'season': 'spring'}
# 300 585 : {'year': 1995, 'season': 'summer'}
# 301 33674 : {'year': 2017, 'season': 'summer'}
# 302 40853 : {'year': 2020, 'season': 'fall'}
# 303 6 : {'year': 1998, 'season': 'spring'}
# 304 3091 : {'year': 2008, 'season': 'spring'}
# 305 5460 : {'year': 2009, 'season': 'spring'}
# 306 38680 : {'year': 2019, 'season': 'spring'}
# 307 36371 : {'year': 2019, 'season': 'fall'}
# 308 1142 : {'year': 2006, 'season': 'summer'}
# 309 15227 : {'year': 2016, 'season': 'fall'}
# 310 11977 : {'year': 2012, 'season': 'fall'}
# 311 512 : {'year': 1989, 'season': 'summer'}
# 312 38003 : {'year': 2019, 'season': 'spring'}
# 313 372 : {'year': 2000, 'season': 'summer'}
# 314 42897 : {'year': 2021, 'season': 'winter'}
# 315 16664 : {'year': 2013, 'season': 'fall'}
# 316 558 : {'year': 2006, 'season': 'winter'}
# 317 3226 : {'year': 2008, 'season': 'winter'}
# 318 40729 : {'year': 2021, 'season': 'spring'}
# 319 35466 : {'year': 2018, 'season': 'winter'}
# 320 38249 : {'year': 2018, 'season': 'fall'}
# 321 6864 : {'year': 2010, 'season': 'spring'}
# 322 19123 : {'year': 2013, 'season': 'summer'}
# 323 38481 : {'year': 2020, 'season': 'winter'}
# 324 49114 : {'year': 2022, 'season': 'winter'}
# 325 34537 : {'year': 2017, 'season': 'spring'}
# 326 7674 : {'year': 2010, 'season': 'fall'}
# 327 12115 : {'year': 2013, 'season': 'winter'}
# 328 32867 : {'year': 2016, 'season': 'fall'}
# 329 10800 : {'year': 2011, 'season': 'fall'}
# 330 25537 : {'year': 2017, 'season': 'fall'}
# 331 45577 : {'year': 2021, 'season': 'summer'}
# 332 6811 : {'year': 2009, 'season': 'fall'}
# 333 18195 : {'year': 2013, 'season': 'fall'}
# 334 1453 : {'year': 1986, 'season': 'spring'}
# 335 37171 : {'year': 2018, 'season': 'summer'}
# 336 34636 : {'year': 2017, 'season': 'summer'}
# 337 22297 : {'year': 2014, 'season': 'fall'}
# 338 18617 : {'year': 2015, 'season': 'fall'}
# 339 1889 : {'year': 2007, 'season': 'summer'}
# 340 138 : {'year': 2003, 'season': 'winter'}
# 341 25681 : {'year': 2015, 'season': 'winter'}
# 342 35677 : {'year': 2018, 'season': 'spring'}
# 343 23623 : {'year': 2015, 'season': 'summer'}
# 344 32843 : {'year': 2019, 'season': 'summer'}
# 345 28171 : {'year': 2015, 'season': 'spring'}
# 346 35838 : {'year': 2017, 'season': 'fall'}
# 347 2150 : {'year': 1990, 'season': 'spring'}
# 348 440 : {'year': 1997, 'season': 'spring'}
# 349 962 : {'year': 2006, 'season': 'spring'}
# 350 1519 : {'year': 2006, 'season': 'fall'}
# 351 40852 : {'year': 2021, 'season': 'winter'}
# 352 41361 : {'year': 2021, 'season': 'spring'}
# 353 39166 : {'year': 2021, 'season': 'winter'}
# 354 33486 : {'year': 2017, 'season': 'spring'}
# 355 28223 : {'year': 2015, 'season': 'winter'}
# 356 32005 : {'year': 2016, 'season': 'spring'}
# 357 38088 : {'year': 2020, 'season': 'winter'}
# 358 7791 : {'year': 2010, 'season': 'spring'}
# 359 28675 : {'year': 2015, 'season': 'spring'}
# 360 9890 : {'year': 2010, 'season': 'fall'}
# 361 30503 : {'year': 2015, 'season': 'fall'}
# 362 4921 : {'year': 1993, 'season': 'winter'}
# 363 12859 : {'year': 2012, 'season': 'fall'}
# 364 853 : {'year': 2006, 'season': 'spring'}
# 365 4107 : {'year': 2008, 'season': 'summer'}
# 366 31715 : {'year': 2016, 'season': 'winter'}
# 367 47 : {'year': 1988, 'season': 'summer'}
# 368 235 : {'year': 1996, 'season': 'winter'}
# 369 40421 : {'year': 2020, 'season': 'summer'}
# 370 49053 : {'year': 2021, 'season': 'fall'}
# 371 35111 : {'year': 2017, 'season': 'summer'}
# 372 36296 : {'year': 2018, 'season': 'spring'}
# 373 50325 : {'year': 2021, 'season': 'fall'}
# 374 232 : {'year': 1998, 'season': 'spring'}
# 375 42977 : {'year': 2020, 'season': 'summer'}
# 376 813 : {'year': 1989, 'season': 'spring'}
# 377 239 : {'year': 2004, 'season': 'fall'}
# 378 18 : {'year': 2004, 'season': 'spring'}
# 379 3701 : {'year': 2008, 'season': 'spring'}
# 380 1430 : {'year': 1979, 'season': 'fall'}
# 381 35857 : {'year': 2018, 'season': 'spring'}
# 382 40435 : {'year': 2020, 'season': 'summer'}
# 383 11597 : {'year': 2012, 'season': 'winter'}
# 384 4477 : {'year': 2008, 'season': 'fall'}
# 385 1827 : {'year': 2007, 'season': 'spring'}
# 386 42249 : {'year': 2021, 'season': 'spring'}
# 387 2236 : {'year': 2006, 'season': 'summer'}
# 388 40911 : {'year': 2020, 'season': 'fall'}
# 389 39792 : {'year': 2020, 'season': 'winter'}
# 390 37962 : {'year': 2020, 'season': 'spring'}
# 391 186 : {'year': 1999, 'season': 'fall'}
# 392 33323 : {'year': 2016, 'season': 'fall'}
# 393 1604 : {'year': 2006, 'season': 'fall'}
# 394 37514 : {'year': 2019, 'season': 'winter'}
# 395 10153 : {'year': 2012, 'season': 'summer'}
# 396 39783 : {'year': 2021, 'season': 'winter'}
# 397 35608 : {'year': 2018, 'season': 'winter'}
# 398 44189 : {'year': 2020, 'season': 'fall'}
# 399 36946 : {'year': 2018, 'season': 'fall'}
# 400 6746 : {'year': 2010, 'season': 'winter'}
# 401 3371 : {'year': 1998, 'season': 'winter'}
# 402 40815 : {'year': 2020, 'season': 'spring'}
# 403 731 : {'year': 2003, 'season': 'fall'}
# 404 30831 : {'year': 2016, 'season': 'winter'}
# 405 15323 : {'year': 2012, 'season': 'summer'}
# 406 37430 : {'year': 2018, 'season': 'fall'}
# 407 44931 : {'year': 2021, 'season': 'summer'}
# 408 2581 : {'year': 2007, 'season': 'fall'}
# 409 6336 : {'year': 2010, 'season': 'winter'}
# 410 42894 : {'year': 2021, 'season': 'winter'}
# 411 49521 : {'year': 2022, 'season': 'winter'}
# 412 4155 : {'year': 2009, 'season': 'fall'}
# 413 721 : {'year': 2002, 'season': 'summer'}
# 414 13759 : {'year': 2012, 'season': 'fall'}
# 415 32282 : {'year': 2016, 'season': 'summer'}
# 416 1364 : {'year': 2001, 'season': 'spring'}
# 417 6467 : {'year': 2010, 'season': 'spring'}
# 418 3702 : {'year': 2008, 'season': 'summer'}
# 419 42497 : {'year': 2020, 'season': 'winter'}
# 420 121 : {'year': 2003, 'season': 'fall'}
# 421 1566 : {'year': 2006, 'season': 'summer'}
# 422 8129 : {'year': 2010, 'season': 'fall'}
# 423 32902 : {'year': 2016, 'season': 'summer'}
# 424 3901 : {'year': 2008, 'season': 'winter'}
# 425 34572 : {'year': 2017, 'season': 'fall'}
# 426 37822 : {'year': 2018, 'season': 'fall'}
# 427 36370 : {'year': 2019, 'season': 'fall'}
# 428 25313 : {'year': 2015, 'season': 'spring'}
# 429 32122 : {'year': 2015, 'season': 'fall'}
# 430 39592 : {'year': 2019, 'season': 'spring'}
# 431 19815 : {'year': 2014, 'season': 'spring'}
# 432 40080 : {'year': 2019, 'season': 'summer'}
# 433 40542 : {'year': 2019, 'season': 'fall'}
# 434 29831 : {'year': 2016, 'season': 'spring'}
# 435 4224 : {'year': 2008, 'season': 'fall'}
# 436 4938 : {'year': 2009, 'season': 'winter'}
# 437 28025 : {'year': 2014, 'season': 'fall'}
# 438 34076 : {'year': 2017, 'season': 'spring'}
# 439 34822 : {'year': 2017, 'season': 'spring'}
# 440 23283 : {'year': 2014, 'season': 'summer'}
# 441 24833 : {'year': 2015, 'season': 'winter'}
# 442 36456 : {'year': 2018, 'season': 'spring'}
# 443 18689 : {'year': 2013, 'season': 'fall'}
# 444 48631 : {'year': 2021, 'season': 'winter'}
# 445 3016 : {'year': 1993, 'season': 'fall'}
# 446 35110 : {'year': 2017, 'season': 'summer'}
# 447 12189 : {'year': 2012, 'season': 'spring'}
# 448 20899 : {'year': 2014, 'season': 'spring'}
# 449 39198 : {'year': 2019, 'season': 'summer'}
# 450 16662 : {'year': 2013, 'season': 'summer'}
# 451 31051 : {'year': 2015, 'season': 'fall'}
# 452 30370 : {'year': 2015, 'season': 'summer'}
# 453 16918 : {'year': 2013, 'season': 'summer'}
# 454 12069 : {'year': 2003, 'season': 'winter'}
# 455 38993 : {'year': 2019, 'season': 'summer'}
# 456 302 : {'year': 1978, 'season': 'spring'}
# 457 3927 : {'year': 2008, 'season': 'fall'}
# 458 9130 : {'year': 2011, 'season': 'winter'}
# 459 4722 : {'year': 2008, 'season': 'fall'}
# 460 40907 : {'year': 2021, 'season': 'winter'}
# 461 1382 : {'year': 2000, 'season': 'winter'}
# 462 21469 : {'year': 2014, 'season': 'summer'}
# 463 24277 : {'year': 2014, 'season': 'fall'}
# 464 6547 : {'year': 2010, 'season': 'spring'}
# 465 2025 : {'year': 2007, 'season': 'spring'}
# 466 21419 : {'year': 2014, 'season': 'spring'}
# 467 2951 : {'year': 2005, 'season': 'summer'}
# 468 17739 : {'year': 2013, 'season': 'fall'}
# 469 135 : {'year': 2001, 'season': 'fall'}
# 470 15059 : {'year': 2012, 'season': 'fall'}
# 471 2449 : {'year': 2005, 'season': 'summer'}
# 472 11771 : {'year': 2012, 'season': 'spring'}
# 473 31658 : {'year': 2017, 'season': 'winter'}
# 474 22145 : {'year': 2014, 'season': 'summer'}
# 475 41402 : {'year': 2021, 'season': 'spring'}
# 476 1367 : {'year': 2004, 'season': 'spring'}
# 477 38668 : {'year': 2020, 'season': 'winter'}
# 478 27833 : {'year': 2016, 'season': 'winter'}
# 479 10643 : {'year': 2010, 'season': 'winter'}
# 480 38081 : {'year': 2019, 'season': 'spring'}
# 481 8425 : {'year': 2011, 'season': 'winter'}
# 482 14713 : {'year': 2012, 'season': 'fall'}
# 483 237 : {'year': 2005, 'season': 'spring'}
# 484 23317 : {'year': 2015, 'season': 'winter'}
# 485 35062 : {'year': 2017, 'season': 'fall'}
# 486 21557 : {'year': 2014, 'season': 'summer'}
# 487 1559 : {'year': 2006, 'season': 'fall'}
# 488 339 : {'year': 1998, 'season': 'summer'}
# 489 4918 : {'year': 2009, 'season': 'winter'}
# 490 1471 : {'year': 1988, 'season': 'spring'}
# 491 2164 : {'year': 2007, 'season': 'spring'}
# 492 27821 : {'year': 2014, 'season': 'fall'}
# 493 3665 : {'year': 1999, 'season': 'fall'}
# 494 1974 : {'year': 2005, 'season': 'spring'}
# 495 48926 : {'year': 2021, 'season': 'fall'}
# 496 10534 : {'year': 2011, 'season': 'winter'}
# 497 42496 : {'year': 2019, 'season': 'fall'}
# 498 47904 : {'year': 2021, 'season': 'spring'}
# 499 18679 : {'year': 2013, 'season': 'fall'}
# 500 1486 : {'year': 1996, 'season': 'spring'}
# 501 851 : {'year': 1993, 'season': 'spring'}
# 502 5681 : {'year': 2009, 'season': 'summer'}
# 503 31251 : {'year': 2015, 'season': 'fall'}
# 504 1943 : {'year': 2006, 'season': 'fall'}
# 505 1257 : {'year': 2002, 'season': 'fall'}
# 506 1914 : {'year': 2007, 'season': 'spring'}
# 507 35788 : {'year': 2017, 'season': 'fall'}
# 508 42923 : {'year': 2021, 'season': 'winter'}
# 509 33161 : {'year': 2016, 'season': 'fall'}
# 510 37870 : {'year': 2020, 'season': 'winter'}
# 511 1506 : {'year': 2006, 'season': 'spring'}
# 512 3167 : {'year': 2008, 'season': 'summer'}
# 513 72 : {'year': 2003, 'season': 'summer'}
# 514 42886 : {'year': 2022, 'season': 'winter'}
# 515 42429 : {'year': 2022, 'season': 'spring'}
# 516 153 : {'year': 2002, 'season': 'spring'}
# 517 3783 : {'year': 2008, 'season': 'winter'}
# 518 34626 : {'year': 2017, 'season': 'summer'}
# 519 2034 : {'year': 2007, 'season': 'spring'}
# 520 25013 : {'year': 2014, 'season': 'fall'}
# 521 27663 : {'year': 2015, 'season': 'spring'}
# 522 889 : {'year': 2006, 'season': 'spring'}
# 523 4901 : {'year': 2010, 'season': 'spring'}
# 524 39565 : {'year': 2019, 'season': 'fall'}
# 525 1482 : {'year': 2006, 'season': 'fall'}
# 526 781 : {'year': 1999, 'season': 'spring'}
# 527 1363 : {'year': 2000, 'season': 'spring'}
# 528 227 : {'year': 2000, 'season': 'spring'}
# 529 589 : {'year': 1986, 'season': 'spring'}
# 530 16706 : {'year': 2013, 'season': 'summer'}
# 531 14513 : {'year': 2012, 'season': 'fall'}
# 532 16049 : {'year': 2013, 'season': 'spring'}
# 533 5365 : {'year': 2008, 'season': 'spring'}
# 534 40174 : {'year': 2021, 'season': 'spring'}
# 535 9204 : {'year': 2010, 'season': 'fall'}
# 536 44235 : {'year': 2021, 'season': 'winter'}
# 537 535 : {'year': 1996, 'season': 'spring'}
# 538 35790 : {'year': 2019, 'season': 'winter'}
# 539 6211 : {'year': 2009, 'season': 'summer'}
# 540 42941 : {'year': 2021, 'season': 'winter'}
# 541 14813 : {'year': 2013, 'season': 'spring'}
# 542 34376 : {'year': 2017, 'season': 'summer'}
# 543 9963 : {'year': 2011, 'season': 'spring'}
# 544 4789 : {'year': 2008, 'season': 'fall'}
# 545 2759 : {'year': 2007, 'season': 'summer'}
# 546 268 : {'year': 1995, 'season': 'fall'}
# 547 16 : {'year': 2005, 'season': 'spring'}
# 548 7054 : {'year': 2010, 'season': 'spring'}
# 549 18661 : {'year': 2013, 'season': 'summer'}
# 550 14807 : {'year': 2013, 'season': 'summer'}
# 551 2563 : {'year': 2007, 'season': 'summer'}
# 552 41781 : {'year': 2021, 'season': 'spring'}
# 553 2167 : {'year': 2007, 'season': 'fall'}
# 554 41461 : {'year': 2022, 'season': 'spring'}
# 555 6421 : {'year': 2009, 'season': 'summer'}
# 556 39468 : {'year': 2019, 'season': 'fall'}
# 557 41169 : {'year': 2021, 'season': 'summer'}
# 558 81 : {'year': 1996, 'season': 'winter'}
# 559 50360 : {'year': 2022, 'season': 'winter'}
# 560 16067 : {'year': 2013, 'season': 'fall'}
# 561 31149 : {'year': 2016, 'season': 'winter'}
# 562 1023 : {'year': 2004, 'season': 'winter'}
# 563 40397 : {'year': 2020, 'season': 'fall'}
# 564 846 : {'year': 2006, 'season': 'spring'}
# 565 1065 : {'year': 1985, 'season': 'spring'}
# 566 34440 : {'year': 2018, 'season': 'spring'}
# 567 44412 : {'year': 2021, 'season': 'winter'}
# 568 23199 : {'year': 2015, 'season': 'winter'}
# 569 7465 : {'year': 2010, 'season': 'winter'}
# 570 30364 : {'year': 2015, 'season': 'summer'}
# 571 2004 : {'year': 2002, 'season': 'fall'}
# 572 27989 : {'year': 2015, 'season': 'spring'}
# 573 38422 : {'year': 2019, 'season': 'winter'}
# 574 40716 : {'year': 2020, 'season': 'spring'}
# 575 6045 : {'year': 2009, 'season': 'fall'}
# 576 33206 : {'year': 2017, 'season': 'winter'}
# 577 2448 : {'year': 2006, 'season': 'winter'}
# 578 49063 : {'year': 2021, 'season': 'spring'}
# 579 36369 : {'year': 2019, 'season': 'summer'}
# 580 39570 : {'year': 2019, 'season': 'fall'}
# 581 9656 : {'year': 2011, 'season': 'winter'}
# 582 4672 : {'year': 2008, 'season': 'summer'}
# 583 5029 : {'year': 2008, 'season': 'fall'}
# 584 7720 : {'year': 2010, 'season': 'spring'}
# 585 35848 : {'year': 2019, 'season': 'spring'}
# 586 30015 : {'year': 2016, 'season': 'summer'}
# 587 12477 : {'year': 2013, 'season': 'fall'}
# 588 36949 : {'year': 2018, 'season': 'spring'}
# 589 861 : {'year': 2006, 'season': 'spring'}
# 590 401 : {'year': 2001, 'season': 'fall'}
# 591 4053 : {'year': 2008, 'season': 'spring'}
# 592 42640 : {'year': 2020, 'season': 'fall'}
# 593 25879 : {'year': 2015, 'season': 'summer'}
# 594 31173 : {'year': 2016, 'season': 'winter'}
# 595 4772 : {'year': 2008, 'season': 'spring'}
# 596 27831 : {'year': 2015, 'season': 'summer'}
# 597 9996 : {'year': 2011, 'season': 'spring'}
# 598 12031 : {'year': 2012, 'season': 'summer'}
# 599 66 : {'year': 2002, 'season': 'spring'}
# 600 387 : {'year': 2002, 'season': 'fall'}
# 601 967 : {'year': 1984, 'season': 'fall'}
# 602 1530 : {'year': 2006, 'season': 'fall'}
# 603 48916 : {'year': 2022, 'season': 'spring'}
# 604 77 : {'year': 2005, 'season': 'fall'}
# 605 20 : {'year': 2002, 'season': 'fall'}
# 606 20507 : {'year': 2014, 'season': 'winter'}
# 607 8740 : {'year': 2010, 'season': 'spring'}
# 608 31174 : {'year': 2015, 'season': 'fall'}
# 609 5682 : {'year': 2009, 'season': 'spring'}
# 610 37932 : {'year': 2020, 'season': 'summer'}
# 611 6171 : {'year': 2009, 'season': 'spring'}
# 612 41611 : {'year': 2020, 'season': 'spring'}
# 613 32615 : {'year': 2017, 'season': 'winter'}
# 614 35382 : {'year': 2017, 'season': 'spring'}
# 615 10721 : {'year': 2011, 'season': 'summer'}
# 616 10049 : {'year': 2011, 'season': 'summer'}
# 617 42916 : {'year': 2021, 'season': 'fall'}
# 618 2154 : {'year': 2006, 'season': 'fall'}
# 619 38408 : {'year': 2019, 'season': 'fall'}
# 620 223 : {'year': 1986, 'season': 'winter'}
# 621 33970 : {'year': 2017, 'season': 'fall'}
# 622 29755 : {'year': 2015, 'season': 'summer'}
# 623 645 : {'year': 2004, 'season': 'winter'}
# 624 36963 : {'year': 2018, 'season': 'winter'}
# 625 5678 : {'year': 2009, 'season': 'fall'}
# 626 7222 : {'year': 2011, 'season': 'winter'}
# 627 1089 : {'year': 1984, 'season': 'summer'}
# 628 4059 : {'year': 2008, 'season': 'summer'}
# 629 44248 : {'year': 2020, 'season': 'fall'}
# 630 34100 : {'year': 2017, 'season': 'summer'}
# 631 38337 : {'year': 2020, 'season': 'fall'}
# 632 21855 : {'year': 2014, 'season': 'summer'}
# 633 2076 : {'year': 1997, 'season': 'spring'}
# 634 16001 : {'year': 2012, 'season': 'fall'}
# 635 416 : {'year': 1992, 'season': 'summer'}
# 636 17265 : {'year': 2013, 'season': 'fall'}
# 637 17549 : {'year': 2013, 'season': 'fall'}
# 638 11113 : {'year': 2011, 'season': 'fall'}
# 639 35968 : {'year': 2018, 'season': 'spring'}
# 640 793 : {'year': 2005, 'season': 'summer'}
# 641 18179 : {'year': 2013, 'season': 'fall'}
# 642 82 : {'year': 1989, 'season': 'winter'}
# 643 31973 : {'year': 2015, 'season': 'fall'}
# 644 15689 : {'year': 2012, 'season': 'fall'}
# 645 21647 : {'year': 2014, 'season': 'spring'}
# 646 4106 : {'year': 2010, 'season': 'spring'}
# 647 14075 : {'year': 2012, 'season': 'fall'}
# 648 31964 : {'year': 2016, 'season': 'spring'}
# 649 49638 : {'year': 2021, 'season': 'summer'}
# 650 38084 : {'year': 2019, 'season': 'fall'}
# 651 73 : {'year': 2005, 'season': 'summer'}
# 652 122 : {'year': 2002, 'season': 'spring'}
# 653 11739 : {'year': 2012, 'season': 'spring'}
# 654 6774 : {'year': 2009, 'season': 'fall'}
# 655 996 : {'year': 1996, 'season': 'spring'}
# 656 42250 : {'year': 2021, 'season': 'winter'}
# 657 7338 : {'year': 2010, 'season': 'winter'}
# 658 2952 : {'year': 2009, 'season': 'spring'}
# 659 11239 : {'year': 2012, 'season': 'fall'}
# 660 1096 : {'year': 1993, 'season': 'summer'}
# 661 24997 : {'year': 2015, 'season': 'spring'}
# 662 33221 : {'year': 2016, 'season': 'spring'}
# 663 16395 : {'year': 2013, 'season': 'winter'}
# 664 2618 : {'year': 1978, 'season': 'fall'}
# 665 658 : {'year': 2005, 'season': 'fall'}
# 666 40615 : {'year': 2020, 'season': 'summer'}
# 667 38349 : {'year': 2019, 'season': 'winter'}
# 668 28 : {'year': 2004, 'season': 'fall'}
# 669 30279 : {'year': 2015, 'season': 'fall'}
# 670 31490 : {'year': 2016, 'season': 'summer'}
# 671 28297 : {'year': 2015, 'season': 'spring'}
# 672 29803 : {'year': 2015, 'season': 'summer'}
# 673 37675 : {'year': 2018, 'season': 'summer'}
# 674 27775 : {'year': 2015, 'season': 'spring'}
# 675 41389 : {'year': 2020, 'season': 'fall'}
# 676 38409 : {'year': 2018, 'season': 'spring'}
# 677 1470 : {'year': 1987, 'season': 'spring'}
# 678 34437 : {'year': 2019, 'season': 'winter'}
# 679 15 : {'year': 2005, 'season': 'spring'}
# 680 9289 : {'year': 2011, 'season': 'spring'}
# 681 14719 : {'year': 2012, 'season': 'fall'}
# 682 16782 : {'year': 2013, 'season': 'spring'}
# 683 1088 : {'year': 1982, 'season': 'fall'}
# 684 29893 : {'year': 2015, 'season': 'summer'}
# 685 34944 : {'year': 2018, 'season': 'winter'}
# 686 6438 : {'year': 2009, 'season': 'spring'}
# 687 31339 : {'year': 2016, 'season': 'fall'}
# 688 2924 : {'year': 2007, 'season': 'fall'}
# 689 790 : {'year': 2006, 'season': 'winter'}
# 690 41497 : {'year': 2021, 'season': 'summer'}
# 691 7062 : {'year': 2010, 'season': 'winter'}
# 692 2829 : {'year': 1996, 'season': 'fall'}
# 693 13331 : {'year': 2012, 'season': 'fall'}
# 694 427 : {'year': 2003, 'season': 'spring'}
# 695 38080 : {'year': 2019, 'season': 'spring'}
# 696 27947 : {'year': 2015, 'season': 'fall'}
# 697 2159 : {'year': 2007, 'season': 'spring'}
# 698 42670 : {'year': 2022, 'season': 'winter'}
# 699 33926 : {'year': 2017, 'season': 'spring'}
# 700 114 : {'year': 2003, 'season': 'fall'}
# 701 12815 : {'year': 2012, 'season': 'spring'}
# 702 995 : {'year': 2006, 'season': 'winter'}
# 703 2752 : {'year': 2007, 'season': 'spring'}
# 704 31098 : {'year': 2016, 'season': 'spring'}
# 705 48580 : {'year': 2021, 'season': 'summer'}
# 706 37786 : {'year': 2018, 'season': 'fall'}
# 707 32995 : {'year': 2016, 'season': 'fall'}
# 708 3228 : {'year': 2008, 'season': 'winter'}
# 709 957 : {'year': 2006, 'season': 'spring'}
# 710 24 : {'year': 2004, 'season': 'fall'}
# 711 11813 : {'year': 2012, 'season': 'winter'}
# 712 48171 : {'year': 2021, 'season': 'fall'}
# 713 2158 : {'year': 2007, 'season': 'spring'}
# 714 22961 : {'year': 2014, 'season': 'fall'}
# 715 14353 : {'year': 2013, 'season': 'winter'}
# 716 26213 : {'year': 2015, 'season': 'winter'}
# 717 2890 : {'year': 2008, 'season': 'summer'}
# 718 35222 : {'year': 2018, 'season': 'winter'}
# 719 3014 : {'year': 1988, 'season': 'winter'}
# 720 3907 : {'year': 1994, 'season': 'spring'}
# 721 934 : {'year': 2006, 'season': 'spring'}
# 722 1594 : {'year': 2006, 'season': 'fall'}
# 723 10080 : {'year': 2011, 'season': 'spring'}
# 724 7711 : {'year': 2010, 'season': 'summer'}
# 725 3572 : {'year': 2008, 'season': 'spring'}
# 726 39195 : {'year': 2019, 'season': 'fall'}
# 727 37435 : {'year': 2019, 'season': 'spring'}
# 728 34438 : {'year': 2017, 'season': 'fall'}
# 729 36563 : {'year': 2018, 'season': 'spring'}
# 730 85 : {'year': 1985, 'season': 'spring'}
# 731 36215 : {'year': 2017, 'season': 'summer'}
# 732 8063 : {'year': 2011, 'season': 'winter'}
# 733 543 : {'year': 2000, 'season': 'summer'}
# 734 37936 : {'year': 2020, 'season': 'summer'}
# 735 25161 : {'year': 2014, 'season': 'summer'}
# 736 6007 : {'year': 2009, 'season': 'spring'}
# 737 38201 : {'year': 2019, 'season': 'winter'}
# 738 2605 : {'year': 2007, 'season': 'summer'}
# 739 11123 : {'year': 2011, 'season': 'fall'}
# 740 20371 : {'year': 2014, 'season': 'winter'}
# 741 20057 : {'year': 2014, 'season': 'winter'}
# 742 9941 : {'year': 2011, 'season': 'spring'}
# 743 6377 : {'year': 2009, 'season': 'summer'}
# 744 12113 : {'year': 2012, 'season': 'spring'}
# 745 10012 : {'year': 2011, 'season': 'summer'}
# 746 780 : {'year': 1998, 'season': 'spring'}
# 747 35075 : {'year': 2017, 'season': 'fall'}
# 748 187 : {'year': 2001, 'season': 'winter'}
# 749 42076 : {'year': 2020, 'season': 'spring'}
# 750 4985 : {'year': 2010, 'season': 'winter'}
# 751 15039 : {'year': 2013, 'season': 'summer'}
# 752 9513 : {'year': 2011, 'season': 'winter'}
# 753 532 : {'year': 1994, 'season': 'spring'}
# 754 8408 : {'year': 2010, 'season': 'summer'}
# 755 30415 : {'year': 2015, 'season': 'fall'}
# 756 49893 : {'year': 2022, 'season': 'winter'}
# 757 30745 : {'year': 2015, 'season': 'winter'}
# 758 1695 : {'year': 2007, 'season': 'winter'}
# 759 18429 : {'year': 2013, 'season': 'fall'}
# 760 37765 : {'year': 2021, 'season': 'spring'}
# 761 30885 : {'year': 2015, 'season': 'fall'}
# 762 26123 : {'year': 2014, 'season': 'spring'}
# 763 22 : {'year': 2001, 'season': 'fall'}
# 764 6505 : {'year': 2003, 'season': 'spring'}
# 765 949 : {'year': 1988, 'season': 'fall'}
# 766 569 : {'year': 1993, 'season': 'winter'}
# 767 18397 : {'year': 2013, 'season': 'fall'}
# 768 32093 : {'year': 2016, 'season': 'spring'}
# 769 6582 : {'year': 2009, 'season': 'fall'}
# 770 23225 : {'year': 2015, 'season': 'winter'}
# 771 40935 : {'year': 2021, 'season': 'winter'}
# 772 46352 : {'year': 2021, 'season': 'fall'}
# 773 37150 : {'year': 2018, 'season': 'winter'}
# 774 50364 : {'year': 2021, 'season': 'fall'}
# 775 39164 : {'year': 2017, 'season': 'fall'}
# 776 2623 : {'year': 1997, 'season': 'winter'}
# 777 23289 : {'year': 2014, 'season': 'summer'}
# 778 36028 : {'year': 2018, 'season': 'spring'}
# 779 29093 : {'year': 2015, 'season': 'spring'}
# 780 14175 : {'year': 2013, 'season': 'winter'}
# 781 24471 : {'year': 2015, 'season': 'winter'}
# 782 429 : {'year': 2005, 'season': 'fall'}
# 783 28725 : {'year': 2015, 'season': 'summer'}
# 784 31741 : {'year': 2016, 'season': 'spring'}
# 785 25517 : {'year': 2014, 'season': 'fall'}
# 786 24921 : {'year': 2015, 'season': 'fall'}
# 787 269 : {'year': 2004, 'season': 'fall'}
# 788 2761 : {'year': 1982, 'season': 'summer'}
# 789 779 : {'year': 1997, 'season': 'spring'}
# 790 37029 : {'year': 2018, 'season': 'spring'}
# 791 40046 : {'year': 2020, 'season': 'winter'}
# 792 249 : {'year': 2000, 'season': 'fall'}
# 793 39534 : {'year': 2020, 'season': 'winter'}
# 794 5680 : {'year': 2009, 'season': 'spring'}
# 795 4280 : {'year': 2008, 'season': 'spring'}
# 796 32380 : {'year': 2016, 'season': 'spring'}
# 797 34021 : {'year': 2017, 'season': 'winter'}
# 798 32547 : {'year': 2016, 'season': 'summer'}
# 799 322 : {'year': 2005, 'season': 'fall'}
# 800 400 : {'year': 1998, 'season': 'winter'}
# 801 17909 : {'year': 2013, 'season': 'summer'}
# 802 35507 : {'year': 2017, 'season': 'summer'}
# 803 4087 : {'year': 2008, 'season': 'fall'}
# 804 34504 : {'year': 2017, 'season': 'summer'}
# 805 4163 : {'year': 2008, 'season': 'fall'}
# 806 3588 : {'year': 2008, 'season': 'spring'}
# 807 849 : {'year': 2006, 'season': 'spring'}
# 808 12445 : {'year': 2012, 'season': 'spring'}
# 809 1921 : {'year': 1984, 'season': 'winter'}
# 810 10521 : {'year': 2011, 'season': 'fall'}
# 811 6586 : {'year': 2009, 'season': 'fall'}
# 812 40215 : {'year': 2020, 'season': 'summer'}
# 813 9465 : {'year': 2010, 'season': 'fall'}
# 814 35798 : {'year': 2018, 'season': 'spring'}
# 815 38770 : {'year': 2019, 'season': 'spring'}
# 816 2035 : {'year': 2007, 'season': 'spring'}
# 817 267 : {'year': 2003, 'season': 'fall'}
# 818 9734 : {'year': 2011, 'season': 'winter'}
# 819 6862 : {'year': 2010, 'season': 'winter'}
# 820 48438 : {'year': 2021, 'season': 'summer'}
# 821 32998 : {'year': 2016, 'season': 'summer'}
# 822 38990 : {'year': 2020, 'season': 'summer'}
# 823 12893 : {'year': 2012, 'season': 'spring'}
# 824 4872 : {'year': 2008, 'season': 'fall'}
# 825 40372 : {'year': 2020, 'season': 'winter'}
# 826 3604 : {'year': 2008, 'season': 'summer'}
# 827 2828 : {'year': 1977, 'season': 'fall'}
# 828 2762 : {'year': 1983, 'season': 'fall'}
# 829 33489 : {'year': 2017, 'season': 'winter'}
# 830 40082 : {'year': 2019, 'season': 'fall'}
# 831 34745 : {'year': 2017, 'season': 'summer'}
# 832 30952 : {'year': 2016, 'season': 'winter'}
# 833 33190 : {'year': 2016, 'season': 'summer'}
# 834 39575 : {'year': 2020, 'season': 'winter'}
# 835 41923 : {'year': 2020, 'season': 'summer'}
# 836 12403 : {'year': 2012, 'season': 'summer'}
# 837 890 : {'year': 1997, 'season': 'winter'}
# 838 1729 : {'year': 2006, 'season': 'fall'}
# 839 795 : {'year': 1991, 'season': 'summer'}
# 840 36796 : {'year': 2017, 'season': 'summer'}
# 841 40858 : {'year': 2020, 'season': 'winter'}
# 842 9088 : {'year': 2011, 'season': 'winter'}
# 843 1172 : {'year': 1997, 'season': 'spring'}
# 844 1485 : {'year': 1996, 'season': 'summer'}
# 845 9724 : {'year': 2011, 'season': 'winter'}
# 846 31478 : {'year': 2016, 'season': 'spring'}
# 847 388 : {'year': 2005, 'season': 'fall'}
# 848 40262 : {'year': 2020, 'season': 'winter'}
# 849 253 : {'year': 2001, 'season': 'spring'}
# 850 16916 : {'year': 2013, 'season': 'winter'}
# 851 23293 : {'year': 2014, 'season': 'spring'}
# 852 42847 : {'year': 2021, 'season': 'fall'}
# 853 41674 : {'year': 2021, 'season': 'winter'}
# 854 21185 : {'year': 2014, 'season': 'spring'}
# 855 1472 : {'year': 1989, 'season': 'fall'}
# 856 10029 : {'year': 2011, 'season': 'summer'}
# 857 2450 : {'year': 2001, 'season': 'spring'}
# 858 1366 : {'year': 2003, 'season': 'spring'}
# 859 7304 : {'year': 2004, 'season': 'spring'}
# 860 7645 : {'year': 2010, 'season': 'winter'}
# 861 9563 : {'year': 2010, 'season': 'fall'}
# 862 12413 : {'year': 2012, 'season': 'spring'}
# 863 34451 : {'year': 2017, 'season': 'fall'}
# 864 14349 : {'year': 2013, 'season': 'winter'}
# 865 5310 : {'year': 2009, 'season': 'fall'}
# 866 22097 : {'year': 2014, 'season': 'spring'}
# 867 8038 : {'year': 2010, 'season': 'spring'}
# 868 15771 : {'year': 2013, 'season': 'spring'}
# 869 397 : {'year': 2001, 'season': 'summer'}
# 870 23777 : {'year': 2015, 'season': 'spring'}
# 871 29830 : {'year': 2015, 'season': 'fall'}
# 872 202 : {'year': 2003, 'season': 'winter'}
# 873 34375 : {'year': 2017, 'season': 'spring'}
# 874 2273 : {'year': 1998, 'season': 'summer'}
# 875 20815 : {'year': 2014, 'season': 'winter'}
# 876 49200 : {'year': 2021, 'season': 'spring'}
# 877 36106 : {'year': 2017, 'season': 'fall'}
# 878 22319 : {'year': 2014, 'season': 'summer'}
# 879 48553 : {'year': 2022, 'season': 'winter'}
# 880 6351 : {'year': 2009, 'season': 'summer'}
# 881 1505 : {'year': 2005, 'season': 'spring'}
# 882 37033 : {'year': 2018, 'season': 'winter'}
# 883 2321 : {'year': 1992, 'season': 'summer'}
# 884 1491 : {'year': 1978, 'season': 'fall'}
# 885 29787 : {'year': 2015, 'season': 'fall'}
# 886 468 : {'year': 2004, 'season': 'winter'}
# 887 451 : {'year': 2003, 'season': 'fall'}
# 888 254 : {'year': 2002, 'season': 'summer'}
# 889 3782 : {'year': 2007, 'season': 'fall'}
# 890 97 : {'year': 2003, 'season': 'spring'}
# 891 4472 : {'year': 2008, 'season': 'summer'}
# 892 9252 : {'year': 2010, 'season': 'summer'}
# 893 4447 : {'year': 2008, 'season': 'spring'}
# 894 33280 : {'year': 2017, 'season': 'fall'}
# 895 29095 : {'year': 2015, 'season': 'spring'}
# 896 21877 : {'year': 2018, 'season': 'summer'}
# 897 43691 : {'year': 2021, 'season': 'summer'}
# 898 33263 : {'year': 2016, 'season': 'fall'}
# 899 1425 : {'year': 1977, 'season': 'fall'}
# 900 2143 : {'year': 2007, 'season': 'spring'}
# 901 7588 : {'year': 2010, 'season': 'spring'}
# 902 40814 : {'year': 2021, 'season': 'winter'}
# 903 875 : {'year': 2004, 'season': 'summer'}
# 904 28881 : {'year': 2015, 'season': 'spring'}
# 905 30727 : {'year': 2017, 'season': 'spring'}
# 906 36702 : {'year': 2018, 'season': 'winter'}
# 907 45055 : {'year': 2021, 'season': 'fall'}
# 908 17949 : {'year': 2012, 'season': 'winter'}
# 909 16870 : {'year': 2014, 'season': 'fall'}
# 910 44218 : {'year': 2020, 'season': 'fall'}
# 911 30902 : {'year': 2015, 'season': 'summer'}
# 912 7044 : {'year': 2009, 'season': 'fall'}
# 913 42344 : {'year': 2020, 'season': 'spring'}
# 914 37873 : {'year': 2018, 'season': 'summer'}
# 915 35320 : {'year': 2017, 'season': 'summer'}
# 916 6768 : {'year': 2009, 'season': 'summer'}
# 917 8142 : {'year': 2010, 'season': 'summer'}
# 918 40956 : {'year': 2020, 'season': 'summer'}
# 919 1824 : {'year': 1983, 'season': 'summer'}
# 920 15809 : {'year': 2013, 'season': 'spring'}
# 921 35082 : {'year': 2017, 'season': 'summer'}
# 922 5630 : {'year': 2009, 'season': 'spring'}
# 923 20431 : {'year': 2014, 'season': 'winter'}
# 924 36593 : {'year': 2018, 'season': 'winter'}
# 925 5781 : {'year': 2009, 'season': 'spring'}
# 926 570 : {'year': 2000, 'season': 'spring'}
# 927 32871 : {'year': 2016, 'season': 'fall'}
# 928 19111 : {'year': 2014, 'season': 'spring'}
# 929 6115 : {'year': 2009, 'season': 'winter'}
# 930 42745 : {'year': 2022, 'season': 'spring'}
# 931 8310 : {'year': 2010, 'season': 'spring'}
# 932 30123 : {'year': 2015, 'season': 'summer'}
# 933 35120 : {'year': 2018, 'season': 'winter'}
# 934 552 : {'year': 1999, 'season': 'spring'}
# 935 2397 : {'year': 2000, 'season': 'winter'}
# 936 1571 : {'year': 2006, 'season': 'fall'}
# 937 35806 : {'year': 2016, 'season': 'spring'}
# 938 11237 : {'year': 2011, 'season': 'fall'}
# 939 11887 : {'year': 2012, 'season': 'summer'}
# 940 13203 : {'year': 2012, 'season': 'spring'}
# 941 3750 : {'year': 2009, 'season': 'winter'}
# 942 19613 : {'year': 2014, 'season': 'summer'}
# 943 1376 : {'year': 2004, 'season': 'spring'}
# 944 10119 : {'year': 2011, 'season': 'spring'}
# 945 10083 : {'year': 2011, 'season': 'spring'}
# 946 5005 : {'year': 2008, 'season': 'fall'}
# 947 21867 : {'year': 2014, 'season': 'fall'}
# 948 80 : {'year': 1979, 'season': 'spring'}
# 949 1092 : {'year': 1982, 'season': 'winter'}
# 950 93 : {'year': 2002, 'season': 'fall'}
# 951 35073 : {'year': 2018, 'season': 'winter'}
# 952 210 : {'year': 1989, 'season': 'spring'}
# 953 154 : {'year': 2001, 'season': 'summer'}
# 954 44196 : {'year': 2021, 'season': 'winter'}
# 955 9930 : {'year': 2010, 'season': 'fall'}
# 956 26 : {'year': 2003, 'season': 'spring'}
# 957 12017 : {'year': 2014, 'season': 'winter'}
# 958 11001 : {'year': 2012, 'season': 'spring'}
# 959 1473 : {'year': 1991, 'season': 'spring'}
# 960 8609 : {'year': 2010, 'season': 'spring'}
# 961 38400 : {'year': 2021, 'season': 'summer'}
# 962 2508 : {'year': 2007, 'season': 'fall'}
# 963 38333 : {'year': 2019, 'season': 'summer'}
# 964 49738 : {'year': 2021, 'season': 'fall'}
# 965 1379 : {'year': 2005, 'season': 'winter'}
# 966 3545 : {'year': 1996, 'season': 'summer'}
# 967 4080 : {'year': 2008, 'season': 'spring'}
# 968 19489 : {'year': 2015, 'season': 'fall'}
# 969 37985 : {'year': 2019, 'season': 'spring'}
# 970 40854 : {'year': 2020, 'season': 'spring'}
# 971 28999 : {'year': 2015, 'season': 'summer'}
# 972 1818 : {'year': 2007, 'season': 'spring'}
# 973 2471 : {'year': 1979, 'season': 'spring'}
# 974 35198 : {'year': 2017, 'season': 'fall'}
# 975 28669 : {'year': 2015, 'season': 'winter'}
# 976 17895 : {'year': 2013, 'season': 'fall'}
# 977 19319 : {'year': 2013, 'season': 'fall'}
# 978 35678 : {'year': 2019, 'season': 'spring'}
# 979 4886 : {'year': 2008, 'season': 'summer'}
# 980 10357 : {'year': 2012, 'season': 'summer'}
# 981 4814 : {'year': 2008, 'season': 'fall'}
# 982 35658 : {'year': 2017, 'season': 'summer'}
# 983 91 : {'year': 1997, 'season': 'winter'}
# 984 1253 : {'year': 2005, 'season': 'fall'}
# 985 43439 : {'year': 2021, 'season': 'spring'}
# 986 7724 : {'year': 2010, 'season': 'summer'}
# 987 39940 : {'year': 2019, 'season': 'fall'}
# 988 38850 : {'year': 2019, 'season': 'fall'}
# 989 29829 : {'year': 2015, 'season': 'summer'}
# 990 407 : {'year': 2003, 'season': 'spring'}
# 991 8311 : {'year': 2010, 'season': 'fall'}
# 992 32673 : {'year': 2016, 'season': 'fall'}
# 993 2753 : {'year': 1991, 'season': 'winter'}
# 994 49587 : {'year': 2022, 'season': 'winter'}
# 995 597 : {'year': 2002, 'season': 'summer'}
# 996 1007 : {'year': 1993, 'season': 'fall'}
# 997 1254 : {'year': 1986, 'season': 'fall'}
# 998 24893 : {'year': 2015, 'season': 'spring'}
# 999 23249 : {'year': 2014, 'season': 'fall'}
# 1000 479 : {'year': 2005, 'season': 'spring'}
# 1001 43299 : {'year': 2021, 'season': 'winter'}
# 1002 37924 : {'year': 2018, 'season': 'summer'}
# 1003 31733 : {'year': 2016, 'season': 'spring'}
# 1004 1520 : {'year': 1993, 'season': 'fall'}
# 1005 966 : {'year': 1992, 'season': 'spring'}
# 1006 39764 : {'year': 2021, 'season': 'spring'}
# 1007 38145 : {'year': 2019, 'season': 'winter'}
# 1008 985 : {'year': 1993, 'season': 'winter'}
# 1009 39014 : {'year': 2019, 'season': 'summer'}
# 1010 37959 : {'year': 2018, 'season': 'summer'}
# 1011 35363 : {'year': 2017, 'season': 'summer'}
# 1012 18153 : {'year': 2013, 'season': 'fall'}
# 1013 19703 : {'year': 2013, 'season': 'fall'}
# 1014 1887 : {'year': 2007, 'season': 'spring'}
# 1015 39196 : {'year': 2019, 'season': 'fall'}
# 1016 9074 : {'year': 2010, 'season': 'fall'}
# 1017 36214 : {'year': 2018, 'season': 'spring'}
# 1018 51083 : {'year': 2022, 'season': 'winter'}
# 1019 317 : {'year': 2005, 'season': 'summer'}
# 1020 31637 : {'year': 2016, 'season': 'winter'}
# 1021 27633 : {'year': 2014, 'season': 'summer'}
# 1022 31433 : {'year': 2018, 'season': 'spring'}
# 1023 6984 : {'year': 2009, 'season': 'winter'}
# 1024 13767 : {'year': 2012, 'season': 'fall'}
# 1025 48375 : {'year': 2021, 'season': 'fall'}
# 1026 1910 : {'year': 1999, 'season': 'fall'}
# 1027 20767 : {'year': 2014, 'season': 'winter'}
# 1028 20159 : {'year': 2013, 'season': 'fall'}
# 1029 37442 : {'year': 2019, 'season': 'winter'}
# 1030 517 : {'year': 2005, 'season': 'fall'}
# 1031 534 : {'year': 1995, 'season': 'spring'}
# 1032 48849 : {'year': 2021, 'season': 'summer'}
# 1033 5074 : {'year': 2009, 'season': 'winter'}
# 1034 1562 : {'year': 2006, 'season': 'fall'}
# 1035 1462 : {'year': 1995, 'season': 'fall'}
# 1036 709 : {'year': 2003, 'season': 'fall'}
# 1037 23755 : {'year': 2014, 'season': 'fall'}
# 1038 34914 : {'year': 2017, 'season': 'summer'}
# 1039 464 : {'year': 2005, 'season': 'winter'}
# 1040 31289 : {'year': 2015, 'season': 'summer'}
# 1041 21339 : {'year': 2015, 'season': 'winter'}
# 1042 1719 : {'year': 2006, 'season': 'fall'}
# 1043 6591 : {'year': 2007, 'season': 'spring'}
# 1044 1279 : {'year': 1982, 'season': 'spring'}
# 1045 43523 : {'year': 2021, 'season': 'summer'}
# 1046 1375 : {'year': 1990, 'season': 'winter'}
# 1047 8514 : {'year': 2010, 'season': 'spring'}
# 1048 978 : {'year': 1998, 'season': 'summer'}
# 1049 6024 : {'year': 2009, 'season': 'spring'}
# 1050 14741 : {'year': 2012, 'season': 'fall'}
# 1051 28479 : {'year': 2015, 'season': 'spring'}
# 1052 38436 : {'year': 2019, 'season': 'summer'}
# 1053 25303 : {'year': 2015, 'season': 'winter'}
# 1054 13119 : {'year': 2014, 'season': 'winter'}
# 1055 47402 : {'year': 2021, 'season': 'winter'}
# 1056 33899 : {'year': 2018, 'season': 'winter'}
# 1057 35860 : {'year': 2018, 'season': 'winter'}
# 1058 10090 : {'year': 2011, 'season': 'winter'}
# 1059 22673 : {'year': 2014, 'season': 'winter'}
# 1060 25015 : {'year': 2015, 'season': 'winter'}
# 1061 1211 : {'year': 1995, 'season': 'fall'}
# 1062 31483 : {'year': 2016, 'season': 'winter'}
# 1063 283 : {'year': 1979, 'season': 'winter'}
# 1064 7193 : {'year': 2009, 'season': 'fall'}
# 1065 51218 : {'year': 2022, 'season': 'winter'}
# 1066 10218 : {'year': 2012, 'season': 'winter'}
# 1067 530 : {'year': 1992, 'season': 'spring'}
# 1068 32370 : {'year': 2016, 'season': 'summer'}
# 1069 2724 : {'year': 1981, 'season': 'summer'}
# 1070 12117 : {'year': 2012, 'season': 'spring'}
# 1071 6033 : {'year': 2009, 'season': 'spring'}
# 1072 1281 : {'year': 2000, 'season': 'fall'}
# 1073 18619 : {'year': 2014, 'season': 'summer'}
# 1074 5835 : {'year': 2009, 'season': 'spring'}
# 1075 8426 : {'year': 2011, 'season': 'winter'}
# 1076 38619 : {'year': 2019, 'season': 'summer'}
# 1077 38777 : {'year': 2018, 'season': 'fall'}
# 1078 20517 : {'year': 2014, 'season': 'winter'}
# 1079 474 : {'year': 1994, 'season': 'summer'}
# 1080 15959 : {'year': 2012, 'season': 'fall'}
# 1081 31704 : {'year': 2015, 'season': 'fall'}
# 1082 8795 : {'year': 2010, 'season': 'fall'}
# 1083 42091 : {'year': 2020, 'season': 'summer'}
# 1084 37804 : {'year': 2020, 'season': 'winter'}
# 1085 95 : {'year': 1999, 'season': 'spring'}
# 1086 40620 : {'year': 2021, 'season': 'summer'}
# 1087 90 : {'year': 1995, 'season': 'spring'}
# 1088 31772 : {'year': 2015, 'season': 'fall'}
# 1089 35240 : {'year': 2017, 'season': 'summer'}
# 1090 41140 : {'year': 2021, 'season': 'summer'}
# 1091 20847 : {'year': 2014, 'season': 'winter'}
# 1092 23775 : {'year': 2014, 'season': 'fall'}
# 1093 2582 : {'year': 1983, 'season': 'spring'}
# 1094 885 : {'year': 1985, 'season': 'fall'}
# 1095 1293 : {'year': 1981, 'season': 'fall'}
# 1096 39959 : {'year': 2019, 'season': 'fall'}
# 1097 8516 : {'year': 2011, 'season': 'summer'}
# 1098 39619 : {'year': 2019, 'season': 'summer'}
# 1099 40429 : {'year': 2021, 'season': 'winter'}
# 1100 740 : {'year': 1993, 'season': 'spring'}
# 1101 531 : {'year': 1993, 'season': 'fall'}
# 1102 2994 : {'year': 2007, 'season': 'summer'}
# 1103 28907 : {'year': 2015, 'season': 'summer'}
# 1104 3603 : {'year': 2007, 'season': 'winter'}
# 1105 34544 : {'year': 2019, 'season': 'spring'}
# 1106 32870 : {'year': 2016, 'season': 'fall'}
# 1107 32863 : {'year': 2016, 'season': 'winter'}
# 1108 41780 : {'year': 2021, 'season': 'spring'}
# 1109 13535 : {'year': 2012, 'season': 'summer'}
# 1110 997 : {'year': 1994, 'season': 'fall'}
# 1111 10092 : {'year': 2011, 'season': 'winter'}
# 1112 38671 : {'year': 2019, 'season': 'summer'}
# 1113 4192 : {'year': 2009, 'season': 'spring'}
# 1114 4811 : {'year': 2009, 'season': 'winter'}
# 1115 1888 : {'year': 2007, 'season': 'winter'}
# 1116 15117 : {'year': 2012, 'season': 'fall'}
# 1117 516 : {'year': 2004, 'season': 'spring'}
# 1118 21659 : {'year': 2014, 'season': 'summer'}
# 1119 2175 : {'year': 2007, 'season': 'spring'}
# 1120 32869 : {'year': 2016, 'season': 'summer'}
# 1121 4454 : {'year': 2007, 'season': 'fall'}
# 1122 2313 : {'year': 1992, 'season': 'summer'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       2 i = 1
#       3 for show in top_shows:
# ----> 4     print(str(i) + " " + str(show['id']) + " : " +str(show['start_season']))
#       5     i = i+1
#
# KeyError: 'start_season'

# %%
def get_friend_list(user):
    # get options for selenium
    firefox_options = Options()
    firefox_options.add_argument('--headless')
    
    # initialize the firefox web driver 
    driver = webdriver.Firefox(WEBDRIVER_PATH, options=firefox_options) 
    
    # define URL
    URL = 'https://www.myanimelist.net/profile/'+user+"/friends/"
    driver.get(URL)
    time.sleep(5)
    # find html element with friends    
    xpath = '/html/body/div[1]/div[2]/div[3]/div[2]/table/tbody/tr/td[2]/div[2]'
    friends_html = driver.find_element_by_xpath(xpath)
    # print(friends_html.text)
    friends_full_list = friends_html.text.split('\n')
    friends_full_list = [i for i in friends_full_list if i]
    i = 0
    friends = []
    for term in friends_full_list:
        if i == 0:
            friends.append(term)
        if i == 2:
            i = -1
        i = i + 1
    return friends

# %%
print(get_friend_list("King_Jode"))
# Out:
# C:\Users\shane\AppData\Local\Temp\ipykernel_10452\327375946.py:7: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(WEBDRIVER_PATH, options=firefox_options)
# ['ohio64', 'turtlemage', 'happydr']
# C:\Users\shane\AppData\Local\Temp\ipykernel_10452\327375946.py:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   friends_html = driver.find_element_by_xpath(xpath)

# %%
get_user_list_ids(client_id, "cheeseflavor")
# Out:
# {'data': [{'node': {'id': 41380,
#     'title': '100-man no Inochi no Ue ni Ore wa Tatteiru',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1506/117717.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1506/117717l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 5,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2021-03-29T00:07:49+00:00',
#     'finish_date': '2020-12-29'}},
#   {'node': {'id': 44881,
#     'title': '100-man no Inochi no Ue ni Ore wa Tatteiru 2nd Season',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1424/117718.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1424/117718l.jpg'}},
#    'list_status': {'status': 'on_hold',
#     'score': 0,
#     'num_episodes_watched': 2,
#     'is_rewatching': False,
#     'updated_at': '2022-03-21T17:38:13+00:00'}},
#   {'node': {'id': 38101,
#     'title': '5-toubun no Hanayome',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1819/97947.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1819/97947l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 8,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2021-03-26T03:06:12+00:00',
#     'finish_date': '2021-03-25'}},
#   {'node': {'id': 39783,
#     'title': '5-toubun no Hanayome ∬',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1775/109514.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1775/109514l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 9,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2021-04-03T07:52:44+00:00',
#     'finish_date': '2021-04-03'}},
#   {'node': {'id': 48548,
#     'title': '5-toubun no Hanayome Movie',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1037/122516.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1037/122516l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2021-04-03T07:36:43+00:00'}},
#   {'node': {'id': 41457,
#     'title': '86',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1987/117507.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1987/117507l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 10,
#     'num_episodes_watched': 11,
#     'is_rewatching': False,
#     'updated_at': '2021-06-20T06:19:14+00:00',
#     'finish_date': '2021-06-19'}},
#   {'node': {'id': 48569,
#     'title': '86 Part 2',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1321/117508.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1321/117508l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 10,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2022-03-19T17:38:51+00:00',
#     'finish_date': '2022-03-19'}},
#   {'node': {'id': 49235,
#     'title': '86 Special Edition: Senya ni Akaku Hinageshi no Saku',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1971/115976.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1971/115976l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2021-06-21T05:53:21+00:00'}},
#   {'node': {'id': 25397,
#     'title': 'Absolute Duo',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/4/68839.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/4/68839l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 3,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2019-12-09T06:00:21+00:00'}},
#   {'node': {'id': 22199,
#     'title': 'Akame ga Kill!',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1429/95946.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1429/95946l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 5,
#     'num_episodes_watched': 24,
#     'is_rewatching': False,
#     'updated_at': '2019-12-09T06:00:25+00:00'}},
#   {'node': {'id': 25013,
#     'title': 'Akatsuki no Yona',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/9/64225.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/9/64225l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 7,
#     'num_episodes_watched': 24,
#     'is_rewatching': False,
#     'updated_at': '2018-02-01

#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/11/75376.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/11/75376l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 10,
#     'num_episodes_watched': 13,
#     'is_rewatching': False,
#     'updated_at': '2018-02-01T03:34:33+00:00'}},
#   {'node': {'id': 28677,
#     'title': 'Yamada-kun to 7-nin no Majo (TV)',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/2/73700.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/2/73700l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 6,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2018-02-01T02:03:33+00:00'}},
#   {'node': {'id': 50346,
#     'title': 'Yofukashi no Uta',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1529/119342.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1529/119342l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2021-11-12T13:25:24+00:00'}},
#   {'node': {'id': 32615,
#     'title': 'Youjo Senki',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/5/82890.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/5/82890l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 8,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2020-02-13T07:20:40+00:00',
#     'finish_date': '2020-02-12'}},
#   {'node': {'id': 49233,
#     'title': 'Youjo Senki II',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1437/115925.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1437/115925l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2021-06-21T05:47:05+00:00'}},
#   {'node': {'id': 37055,
#     'title': 'Youjo Senki Movie',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1249/117182.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1249/117182l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2020-02-13T07:21:20+00:00'}},
#   {'node': {'id': 35507,
#     'title': 'Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e (TV)',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/5/86830.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/5/86830l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 6,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2021-03-29T00:24:21+00:00'}},
#   {'node': {'id': 51096,
#     'title': 'Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e (TV) 2nd Season',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1763/121259.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1763/121259l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2022-02-21T17:29:45+00:00'}},
#   {'node': {'id': 51180,
#     'title': 'Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e (TV) 3rd Season',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1613/121275.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1613/121275l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2022-03-07T03:33:21+00:00'}},
#   {'node': {'id': 36726,
#     'title': 'Yuragi-sou no Yuuna-san',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1462/98802.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1462/98802l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2020-11-25T03:05:28+00:00'}},
#   {'node': {'id': 40911,
#     'title': 'Yuukoku no Moriarty',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1464/108330.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1464/108330l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 10,
#     'num_episodes_watched': 11,
#     'is_rewatching': False,
#     'updated_at': '2021-03-29T00:24:35+00:00',
#     'finish_date': '2020-12-20'}},
#   {'node': {'id': 43325,
#     'title': 'Yuukoku no Moriarty 2nd Season',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1200/111522.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1200/111522l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 10,
#     'num_episodes_watched': 13,
#     'is_rewatching': False,
#     'updated_at': '2021-07-08T07:04:25+00:00',
#     'finish_date': '2021-07-08'}},
#   {'node': {'id': 49733,
#     'title': 'Yuukoku no Moriarty OVA',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1158/119868.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1158/119868l.jpg'}},
#    'list_status': {'status': 'plan_to_watch',
#     'score': 0,
#     'num_episodes_watched': 0,
#     'is_rewatching': False,
#     'updated_at': '2021-10-15T04:13:07+00:00'}},
#   {'node': {'id': 50175,
#     'title': 'Yuusha, Yamemasu',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1934/122301.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1934/122301l.jpg'}},
#    'list_status': {'status': 'watching',
#     'score': 0,
#     'num_episodes_watched': 3,
#     'is_rewatching': False,
#     'updated_at': '2022-04-20T06:52:59+00:00'}},
#   {'node': {'id': 37976,
#     'title': 'Zombieland Saga',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1094/95453.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1094/95453l.jpg'}},
#    'list_status': {'status': 'completed',
#     'score': 8,
#     'num_episodes_watched': 12,
#     'is_rewatching': False,
#     'updated_at': '2018-12-21T05:52:46+00:00',
#     'finish_date': '2018-12-20'}},
#   {'node': {'id': 40174,
#     'title': 'Zombieland Saga: Revenge',
#     'main_picture': {'medium': 'https://api-cdn.myanimelist.net/images/anime/1118/115156.jpg',
#      'large': 'https://api-cdn.myanimelist.net/images/anime/1118/115156l.jpg'}},
#    'list_status': {'status': 'watching',
#     'score': 0,
#     'num_episodes_watched': 4,
#     'is_rewatching': False,
#     'updated_at': '2021-05-06T23:00:48+00:00'}}]}

# %%
def get_friends_preference(client_id, username, content_type='anime'):
    show_list = {}
    friends = get_friend_list(username)
    for friend in friends:
        s = get_user_list_ids(client_id, friend, content_type=content_type, fields='list_status')
        for node in s['data']:
            if not node['list_status']['score'] == 0:
                show_id = node['node']['id']
                if show_id in show_list.keys():
                    show_list[show_id] = {'count' : show_list[show_id]['count']+1, 'avg' : (show_list[show_id]['avg']*show_list[show_id]['count']+node['list_status']['score'])/(show_list[show_id]['count']+1)}
                else:
                    show_list[show_id] = {'count' : 1, 'avg' : node['list_status']['score']}
    return show_list

# %%
print(get_friends_preference(client_id, 'turtlemage'))
# Out:
# C:\Users\shane\AppData\Local\Temp\ipykernel_10452\2279019962.py:7: DeprecationWarning: firefox_profile has been deprecated, please pass in an Options object
#   driver = webdriver.Firefox(WEBDRIVER_PATH, options=firefox_options)
# C:\Users\shane\AppData\Local\Temp\ipykernel_10452\2279019962.py:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   friends_html = driver.find_element_by_xpath(xpath)
# {9919: {'count': 2, 'avg': 7.5}, 1575: {'count': 7, 'avg': 9.285714285714286}, 2904: {'count': 6, 'avg': 9.5}, 28121: {'count': 3, 'avg': 7.666666666666667}, 37347: {'count': 2, 'avg': 8.0}, 40454: {'count': 2, 'avg': 8.5}, 6702: {'count': 2, 'avg': 8.5}, 22043: {'count': 2, 'avg': 8.5}, 35972: {'count': 2, 'avg': 8.0}, 5114: {'count': 5, 'avg': 8.2}, 25159: {'count': 1, 'avg': 8}, 37210: {'count': 1, 'avg': 8}, 38472: {'count': 1, 'avg': 10}, 39988: {'count': 1, 'avg': 10}, 40748: {'count': 8, 'avg': 8.75}, 40750: {'count': 2, 'avg': 6.5}, 38000: {'count': 9, 'avg': 8.777777777777779}, 30831: {'count': 4, 'avg': 7.25}, 32937: {'count': 4, 'avg': 7.0}, 38040: {'count': 3, 'avg': 8.0}, 37984: {'count': 1, 'avg': 8}, 17265: {'count': 2, 'avg': 8.0}, 23321: {'count': 2, 'avg': 6.5}, 40496: {'count': 1, 'avg': 8}, 32182: {'count': 6, 'avg': 8.5}, 37510: {'count': 6, 'avg': 8.833333333333334}, 39535: {'count': 6, 'avg': 8.833333333333334}, 23755: {'count': 2, 'avg': 8.0}, 34577: {'count': 2, 'avg': 8.0}, 39701: {'count': 1, 'avg': 7}, 31722: {'count': 2, 'avg': 7.5}, 21: {'count': 6, 'avg': 8.666666666666666}, 30276: {'count': 7, 'avg': 8.714285714285714}, 34134: {'count': 6, 'avg': 7.666666666666667}, 29803: {'count': 2, 'avg': 7.5}, 31240: {'count': 2, 'avg': 8.0}, 39587: {'count': 2, 'avg': 8.0}, 33255: {'count': 1, 'avg': 8}, 16498: {'count': 7, 'avg': 8.428571428571429}, 25777: {'count': 6, 'avg': 7.833333333333333}, 35760: {'count': 7, 'avg': 8.714285714285714}, 38524: {'count': 7, 'avg': 9.428571428571429}, 40028: {'count': 5, 'avg': 9.6},